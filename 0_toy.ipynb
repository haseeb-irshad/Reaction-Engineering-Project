# %% [markdown]
# # Toy Case
#
# This case employs a simple reaction `A > B` performed in a batch reactor to introduce the provided modelling environment.
#
# <div><center><img src="https://upload.wikimedia.org/wikipedia/commons/1/15/Batch_reactor_STR.svg" width="150"/></center></div>
#
# The mass balance equation for batch reactor is
# $$\frac{dc}{dt} = r_r$$
# The reaction rate constant of `A > B` follows Arrhenius equation
# $$k = A\cdot\exp{(-\frac{E_a}{RT})}$$
# We reparameterise Arrhenius with reference to 20 oC
# $$k = k_{ref}\cdot\exp{(-\frac{E_a}{R}(\frac{1}{T} - \frac{1}{293.15}))}$$
# The reaction rate follows power law with respect to concentrations of reactants
# $$r_r = k\prod c^n$$

# %%
# Import required python libraries
# Run this cell to set up the modelling environment
import pandas as pd
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

# Define the phenomenon dictionary to define the model structure
# A dictionary is a key-value mapping. For more info, please look 
# at https://docs.python.org/3/tutorial/datastructures.html#dictionaries
# Mass accumulation and flow pattern phenomenons are given in string, 
# Mass transport phenomenons are collected in a list, though it's empty here.
phenos = {
    "Mass accumulation":    "Batch",
    "Flow pattern":         "Well_Mixed",
    "Mass transport":       [],
}

# Import the toy case study which we'll work on in this notebook
from cases.toy_case import ToyCase
toy_case = ToyCase(phenos)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %% [markdown]
# #### Parameter Setup
# As modelling parameters are associated with different dimensions (solid, liquid, stream, reaction, and species)
#
# All parameters are indicated as a dictionary as
# ```
# {
#     "param":    "xxx",
#     "solid":    "xxx",
#     "gas":      "xxx",
#     "stream":   "xxx",
#     "reaction": "xxx",
#     "species":  "xxx"
# }
# ```
# in this provided modelling environment.
#
# Example parameter dictionaries:
# > - **Operation parameters**
# >   - {"param": "Temperature"}
# >   - {"Param": "Concentration", "stream": "Stream_1", "species": "A"}
# > Concentration is associated with stream and species
# > - **Kinetics parameters**
# >   - {"param": "Activation_Energy", "stream": "Stream_1", "reaction": "A > B"}
# >   - {"param": "Referenced_Reaction_Rate_Constant", "stream": "Stream_1", "reaction": "A > B"}
# > Activation_Energy and Referenced_Reaction_Rate_Constant are associated with stream and reaction
#
# #### Unit Setup
#
# Parameter setup can be found in the method `toy_case.var2unit()`
#
# | Parameter                         | Unit   |
# | --------------------------------- | ------ |
# | Referenced_Reaction_Rate_Constant |        |
# | Activation_Energy                 | kJ/mol |
# | Temperature                       | oC     |
# | Concentration                     | mol/L  |
# | Batch_Time                        | min    |

# %% [markdown]
# ### Model Simulation
# - Print model kinetics parameters and operation parameters
# - Set operation condition example and plot the concentration curves against operation time
# - Plot B concentration profiles at varied temperatures
# - Plot B concentration profiles at varied initial A concentrations

# %%
# List reaction parameters
print("Reaction parameters:")
for reaction_param in toy_case.reaction_params():
    print(reaction_param)
# Out:
# Reaction parameters:
# ({'param': 'Activation_Energy', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 80.0)
# ({'param': 'Referenced_Reaction_Rate_Constant', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 0.0001)
# ({'param': 'Stoichiometric_Coefficient', 'reaction': 'A > B', 'species': 'A'}, -1)
# ({'param': 'Stoichiometric_Coefficient', 'reaction': 'A > B', 'species': 'B'}, 1)
# ({'param': 'Partial_Order', 'reaction': 'A > B', 'species': 'A'}, 1)

# %%
# List operation parameters
print("Operation parameters:")
for operation_param in toy_case.operation_params():
    print(operation_param)
# Out:
# Operation parameters:
# ({'param': 'Concentration', 'stream': 'Batch_Feed', 'species': 'A'}, None)
# ({'param': 'Temperature'}, None)
# ({'param': 'Batch_Time'}, None)

# %%
# Model simulation and plot concentration profiles
# A concentration   [A] = 1 mol/L
# Temperature       T = 50.0 oC
# Batch time        t_b = 60.0 min
operation_params = [
    ({"param": "Concentration", "stream": "Batch_Feed", "species": "A"}, 1.0), # mol/L
    ({"param": "Temperature"}, 50.0), # oC
    ({"param": "Batch_Time"}, 60.0), # min
]
toy_case.plot_simulation_profiles(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="68e78a6e-1a29-4f0d-a75d-66f481277772" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("68e78a6e-1a29-4f0d-a75d-66f481277772")) {                    Plotly.newPlot(                        "68e78a6e-1a29-4f0d-a75d-66f481277772",                        [{"hovertemplate":"Species=A\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eConcentration (mol\u002fL)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"A","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAzMzMzMzPTPzMzMzMzM+M\u002fzczMzMzM7D8zMzMzMzPzPwAAAAAAAPg\u002fzczMzMzM\u002fD\...\\...\u002fNMQJqZmZmZGU1AAAAAAABATUBmZmZmZmZNQM3MzMzMjE1AMzMzMzOzTUCamZmZmdlNQAAAAAAAAE5A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA8D+N+R+54U7vP0y9QeyXoe4\u002f+8HuGg347T8IQCqsLFLtP+3ieF7ir+w\u002fa7KqWRoR7D+Uz8FHwXXrP5q+RmbE3eo\u002fv9B\u002f1xBJ6j9StwQulLfpP\u002fqLbnI8Kek\u002fu9BXI\u002fid6D\u002f6b1w1thXoP3e8GRNmkOc\u002fTnEunfcN5z\u002f7sToqW47mP1UK4IaBEeY\u002fFRez\u002fFqX5T\u002fsl1Q71x\u002flP6x+WKvnquQ\u002fFUKaIX445D+IwlDZjMjjPwNKDnQGW+M\u002fI4zA+d3v4j8lprDYBofiP+Ieg+V0IOI\u002f2OY3Wxy84T8fWCrb8VnhP89oXVjo+eA\u002f40D23vGb4D8PuzzrAkDgP0UizIsgzN8\u002f5FygBB4c3z+gXwP96G\u002fePx3HU8Zsx90\u002f\u002fpJBR5Ui3T\u002fpJc77ToHcP3xFTPWG49s\u002fdb382SpJ2z9u7VkqJrLaP6L1\u002fklkHto\u002f4y+gItON2T+QFKcUYQDZP486Mvf8ddg\u002fSVcVGJbu1z+yPtk7HGrXP0Xju51\u002f6NY\u002fBFaw77Bp1j95xl5aoe3VP0+IdXdCdNU\u002fO3Zt2IP91D+tFiqIVYnUP2Bv\u002fVWpF9Q\u002fXBtUb3Go0z\u002fxSrVfoDvTP7nDwhAp0dI\u002fmOA4yv5o0j+9ke4xFQPSP6Bc1Utgn9E\u002fA1z5edQ90T9KY9hgZt7QPwidj\u002fQGgdA\u002fl7s+1qgl0D8orMuxgZjPP5vNtEGI6c4\u002fgpaOR1A+zj80iFlRxZbNP2vqwI\u002fT8sw\u002fPcsa1mdSzD8d\u002f2eab7XLP94gVPXYG8s\u002fs5E1opKFyj8reQ3\u002fi\u002fLJPzXFhwy1Ysk\u002fHir7bf7VyD+RImlpWUzIP5nvfee3xcc\u002fopiQcwxCxz9s66I7SsHGP9IlqD1kQ8Y\u002fVmnXbDvIxT8W\u002fu9UuU\u002fFP9LRYhvP2cQ\u002fnFOvT25mxD\u002fcc2PriPXDP1SkG1IRh8M\u002fG9iCUfoawz+Zg1IhN7HCP5WcUmO7ScI\u002fJJpZI3vkwT+0dEzXaoHBPwymHl9\u002fIME\u002fQinSBK7BwD\u002fKend87GTAP2uYLeQwCsA\u002ffAJEiONivz9vayEdTLW+P0BviD+KC74\u002fV8WH4YtlvT8sCQV+J8O8P6KTffBAJLw\u002ffcZjbMSIuz8ZN0qxnvC6P26u4wq9W7o\u002fGSkDUQ3KuT9M15vnfTu5P9ocwb79r7g\u002fNZGmUnwnuD9o\u002f5+r6aG3Px5mIV42H7c\u002foPe+ilOftj\u002fTGS3eMiK2PzpmQJHGp7U\u002f9antaAEwtT+\u002f5Um21rq0P\u002fdNilY6SLQ\u002fkUoEsyDYsz9AU9dtfWqzP7G6IXs2\u002f7I\u002fE9lw3TqWsj+SdaHIfS+yP2Bz4NLyyrE\u002fvdGq9I1osT\u002fvq82IQwixP0g5ZkwIqrA\u002fIM3hXtFNsD+7rfuDKOevP9rDj7ONNq8\u002fiys72b6Jrj\u002fQa1lGqeCtP79D5hA7O60\u002ffKp9E2OZrD9Fz1vtEPurP2YZXQI1YKs\u002fQCj+esDIqj9I01tEpTSqP+9XdfTSo6k\u002ffvCJVyEWqT9ntoOOeYuoP4KzJK7KA6g\u002ftbw0RwR\u002fpz\u002fzcYFmFv2mPzk+3pTxfaY\u002flVck14YBpj8cvzKux4elP\u002fNA7hamEKU\u002fTXRBihScpD9luxz9BSqkP4hDduBtuqM\u002fDAVKIUBNoz9Uw5koceKiP9EMbdv1eaI\u002f\u002fjrRmsMToj9nctlD0K+hP5+ini8STqE\u002fmdb+xH3uoD8F5NJs+ZCgP9Bog+N2NaA\u002f0rshwNW3nz8AuaDTlAifPwg817AVXZ4\u002fS\u002fjBp0O1nT+r4QapChGdP4cs9UVXcJw\u002fxE2FsBbTmz\u002fC+li7NjmbP2Qpu9mlopo\u002fDBCgH1MPmj+jJaVBLn+ZP4ghEZUn8pg\u002foPvTDzBomD9U7IZIOeGXP4ZsbHY1XZc\u002foDVwcRfclj8EcCAzz12WP62NEGo94pU\u002fuHl9hlBplT+bjZrN+fKUP\u002fXlcfMqf5Q\u002fi2LkGtYNlD9MpqnV7Z6TP0YXUCRlMpM\u002ftN48di\u002fIkj\u002f36KupQGCSP5TlrwuN+pE\u002fOUcyWAmXkT+5Q\u002fO5qjWRPw7Uicpm1pA\u ...

# %%
# B concentration profiles under vared temperatures
# Set temperature to a list of values: 25.0, 50.0, 75.0, 100.0
operation_params = [
    ({"param": "Concentration", "stream": "Batch_Feed", "species": "A"}, 1.0), # mol/L
    ({"param": "Temperature"}, [25.0, 50.0, 75.0, 100.0]), # oC
    ({"param": "Batch_Time"}, 60.0), # min
]
toy_case.plot_product_profile_with_temperatures(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="d83751e8-57cb-4ecb-865a-76663ff0bc54" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d83751e8-57cb-4ecb-865a-76663ff0bc54")) {                    Plotly.newPlot(                        "d83751e8-57cb-4ecb-865a-76663ff0bc54",                        [{"hovertemplate":"Temperature (oC)=25.0\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eB concentration (mol\u002fL)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"25.0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"25.0","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAzMzMzMzPTPzMzMzMzM+M\u002fzczMzMzM7D8zMzMzMzPzPwAAAAAAAPg\u002fzczMzMzM\u002fD\...\\...\u002fNMQJqZmZmZGU1AAAAAAABATUBmZmZmZmZNQM3MzMzMjE1AMzMzMzOzTUCamZmZmdlNQAAAAAAAAE5A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACKYwWR9nZdP+mudgMucG0\u002fGYRm+A0Pdj\u002fYPxWko2J9P0ttsAhtWYI\u002f4lPn79j\u002fhT\u002fGeztHlqSJP2ZfgeClR40\u002fqGu7RYR0kD8P3uyLX0SSPzrzsyplE5Q\u002fbpfviZXhlT\u002f8tn4R8a6XPzA+QCl4e5k\u002fVhkTOStHmz+4NNaoChKdP6h8aOAW3J4\u002ftm7UI6hSoD+qITuj2zahP1jNVyKmGqI\u002f4+cZ1Qf+oj9y53DvAOGjP88t26SRw6Q\u002fmtvDErqlpT+c2bJdeoemP+IYvLXSaKc\u002fdorzSsNJqD9kH21NTCqpP7zIPO1tCqo\u002find2Wijqqj\u002faHC7Fe8mrP7ipd11oqKw\u002fNQ9nU+6GrT9YPhDXDWWuPzMohxjHQq8\u002f597vIw0QsD8d+JbKg36wP0HYQpjH7LA\u002f2Xf9pNhasT9sz9AIt8ixP4gzmdpiNrI\u002frt4WLdyjsj\u002fTiwsXIxGzPwYLwq83frM\u002fVCyFDhrrsz\u002fHv59Kyle0P26VXHtIxLQ\u002fVH0GuJQwtT+GR+gXr5y1PxHETLKXCLY\u002fAMN+nk50tj9iFMnz09+2P0GIdsknS7c\u002fqu7RNkq2tz+sFyZTOyG4P1DTvTX7i7g\u002fpPHj9Yn2uD\u002fkxOKq52C5P5G1jmgUy7k\u002ftDSPQhA1uj+1snVP2566P\u002fqf06V1CLs\u002f8Ww6XN9xuz\u002f\u002fiTuJGNu7P45naEMhRLw\u002fBnZSofmsvD\u002fNJYu5oRW9P1Hno6IZfr0\u002f9youc2HmvT8pYbtBeU6+P0z63CRhtr4\u002fzmYkMxkevz8VFyODoYW\u002fP4d7aiv67L8\u002fSQJGoREqwD9zM+Vujl3AP9WDGoXzkMA\u002fXRgX7kDEwD\u002fvIfK0dvfAP2c7veSUKsE\u002fommEiJtdwT95G06ripDBP8IpG1hiw8E\u002fT9fmmSL2wT\u002fz0KZ7yyjCP38tSwhdW8I\u002fuG2+SteNwj9vfOVNOsDCP2WunxyG8sI\u002fYsLGwbokwz8h4S5I2FbDP2edprreiMM\u002f7PP2I866wz9tS+OOpuzDP5t0KQZoHsQ\u002fM6qBlBJQxD\u002fbkJ5EpoHEP0w3LSEjs8Q\u002fLRbVNInkxD8lEDiK2BXFP+Fx8isRR8U\u002fAfKaJDN4xT8nscJ+PqnFP\u002fM59UQz2sU\u002fAoG4gRELxj\u002fp5Iw\u002f2TvGP0Mu7YiKbMY\u002fpY9OaCWdxj+bpSDoqc3GP7x2zRIY\u002fsY\u002fj3O58m8uxz+fdkOSsV7HP3LExPvcjsc\u002fjguROfK+xz9zZPZV8e7HP6NRPVvaHsg\u002fmL+oU61OyD\u002fLBHZJan7IP7Th3EYRrsg\u002fy4APVqLdyD9+djqBHQ3JPzvBhNKCPMk\u002fcckPVNJryT+MYfcPDJvJP\u002fLFURAwysk\u002fA50vXz75yT8n95sGNyjKP7lOnBAaV8o\u002fG4gwh+eFyj+g8VJ0n7TKP6VD+OFB48o\u002ffKAP2s4Ryz94lIJmRkDLP+kVNZGobss\u002fHIUFZPWcyz9arMzoLMvLP+m\u002fXSlP+cs\u002fEl6GL1wnzD8Wjw4FVFXMPzPFuLM2g8w\u002fptxBRQSxzD+qG2HDvN7MP3cyyDdgDM0\u002fQzsjrO45zT8+uhgqaGfNP5mdSbvMlM0\u002ffz1RaRzCzT8fXMU9V+\u002fNP54lNkJ9HM4\u002fITAugI5Jzj\u002fHezIBi3bOP7lyws5yo84\u002fDOlX8kXQzj\u002fdHGd1BP3OP0W2XmGuKc8\u002fWsenv0NWzz8rzKWZxILPP8yqtvgwr88\u002fRbMy5ojbzz\u002fTT7Y15gPQP\u002fzJ2Mj9GdA\u002fHo8kMQsw0D86mzpzDkbQP1MfuZMHXNA\u002fZYE7l\u002fZx0D9uXFqC24fQP2yAq1m2ndA\u002fVvLBIYez0D8p7C3fTcnQP9vcfJYK39A\u002fZWg5TL300D+6Z+sEZgrRP8\u002foF8UEINE\u002fly5BkZk10T8EseZtJEvRPwUdhV+lYNE\u002fi1SWahx20T+AbpGTiYvRP9O26t7soNE\u002fbq4TUUa20T88C3vulcvRPyO4jLvb4NE\u002fC9WxvBf20T\u002fZtlD2SQvSP3LnzGxyINI\u002fuCWHJJE10j+OZd0hpkrSP9TPKmmxX9I\u002faMLH\u002frJ00j8o0AnnqonSP\u002 ...

# %%
# B concentration profiles under vared A concentrations
# Set A concentration to a list of values: [0.5, 1.0, 1.5, 2.0]
operation_params = [
    ({"param": "Concentration", "stream": "Batch_Feed", "species": "A"}, [0.5, 1.0, 1.5, 2.0]), # mol/L
    ({"param": "Temperature"}, 50.0), # oC
    ({"param": "Batch_Time"}, 60.0), # min
]
toy_case.plot_product_profile_with_A_concs(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="19d7d655-c567-4405-a321-c6cbf8be64b6" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("19d7d655-c567-4405-a321-c6cbf8be64b6")) {                    Plotly.newPlot(                        "19d7d655-c567-4405-a321-c6cbf8be64b6",                        [{"hovertemplate":"A concentration (mol\u002fL)=0.5\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eB concentration (mol\u002fL)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.5","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0.5","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAzMzMzMzPTPzMzMzMzM+M\u002fzczMzMzM7D8zMzMzMzPzPwAAAAAAAPg\u002fzczMzMzM\u002fD\...\\...\u002fNMQJqZmZmZGU1AAAAAAABATUBmZmZmZmZNQM3MzMzMjE1AMzMzMzOzTUCamZmZmdlNQAAAAAAAAE5A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAADZEk5xyiOGPwZZ8Q575pU\u002feYwMgZI\u002foD+hCm7UlG6lPzNpoO7mgKo\u002fuEOtRyZ3rz+xpUG79yiyP7XseK7siLQ\u002fHC0Xzbzbtj9NMTE5ryG5P86rsFkLW7s\u002f0vAfNxiIvT9qef4JG6m\u002fP7lxYJ0r38A\u002f0XjoMAfkwT\u002fExcYjQOPCP8JeJXL13MM\u002fadwoMEXRxD++afCJTMDFPzTElcMnqsY\u002fxFGzp\u002fOOxz9ZzrIf0G7IP76hHszYSck\u002f9nymMiggyj9AA\u002fQT2PHKPxrKqmsBv8s\u002fQ1locLyHzD+2KsSTIEzNP6qqT4JEDM4\u002fmTeWIz7Izj84Ih2aIoDPPwTdliQDGtA\u002f2bTVlAFy0D8knRWFGcjQP\u002f+JP4JVHNE\u002fnphT1L9u0T9JD2l+Yr\u002fRP2ddrj5HDtI\u002fchtpjndb0j8AC\u002fah\u002fKbSP8EWyWjf8NI\u002feVJtjSg50z8I+4R14H\u002fTP00zkowPxdM\u002fCFwE778I1D9A8FhF+krUP54MrKjGi9Q\u002fN27e+yzL1D+McpXrNAnVP4kXO+7lRdU\u002fivv9Q0eB1T9RXdH2X7vVPxEcbdo29NU\u002faLdNjNIr1j9cT7RzOWLWP8QxcJhyl9Y\u002f580fp4XL1j\u002feGMIBef7WP99+ZNtSMNc\u002fGjukPBlh1z+7V64D0pDXP++tP+SCv9c\u002f3+WkZzHt1z+wdrrs4hnYP4Km7KecRdg\u002fd4o3o2Nw2D8aRF7aPJrYP4sktD4vw9g\u002fJHIQnEDr2D+x5gXXdRLZP5lZHrDTONk\u002f5r\u002faw15e2T89LLOKG4PZP+XOFlkOp9k\u002fwfVrXzvK2T9TDBCqpuzZP72bVyFUDto\u002fwUqOiUcv2j+63faChE\u002faP6c2y4kOb9o\u002fJlU89uiN2j9uVnL8FqzaP1t1jKybydo\u002fYwqh8nnm2j+fi72WtALbP2VpRqlOHts\u002fyLLnbE852z9+eQ9cu1PbP5RsmriVbds\u002f\u002f0EqreGG2z+StiVNop\u002fbPwCOuJTat9s\u002f3JLTaI3P2z+fliyXvebbP5xxPtZt\u002fds\u002fDANJxaAT3D8DMVHsWCncP33oILyYPtw\u002fUh1HjmJT3D85yheluGfcP8\u002fwqyude9w\u002fj5nhNRKP3D\u002fT01vAGaLcP9q1grC1tNw\u002frbFZQOjG3D+cpPYkttjcP3Fg4RMi6tw\u002fQujpNy773D8kH2ys3AvdPyXIT30vHN0\u002fTIYIpygs3T+e3JUWyjvdPxkug6kVS90\u002ft73nLQ1a3T9prmZismjdPyEDL\u002fYGd90\u002fxp77iAyF3T89RBOrxJLdP2iWSN0woN0\u002fHRj6kFKt3T8yLBIoK7rdP3cVB\u002fW7xt0\u002ft\u002fbaOgbT3T9t8ICMC9\u002fdPyo0R9nO6t0\u002foXilwVH23T+79sWrlQHeP0Q3\u002fvKbDN4\u002f6RLP52UX3j9AsuTP9CHeP7qNFuZJLN4\u002fr21nWmY23j9YagVSS0DeP9LrSef5Sd4\u002fHaq5KXNT3j8YrQQeuFzeP4lMBr7JZd4\u002fFjDF+Khu3j9MT3OyVnfeP5LxbcTTf94\u002fOa49\u002fSCI3j92bJYgP5DeP8hlNVsvmN4\u002fl7bd4\u002fOf3j9E+zXGjafeP3HDc+\u002f9rt4\u002fASD+RUW23j8so22pZL3eP25gjPJcxN4\u002fkuxV8y7L3j+wXfd229HePyZLz0Fj2N4\u002foc1tEcfe3j8bf5ScB+XeP9V6NpMl694\u002fYV14niHx3j+URLBg\u002fPbeP5jPZXW2\u002fN4\u002f2x5ScVAC3z8b1F\u002fiygffP18Sq08mDd8\u002fDTVglGMS3z\u002fRTuAGhBffP45aB1CIHN8\u002fPwrmDXEh3z8rBB3aPibfP+\u002fi3EnyKt8\u002fdjXm7Ysv3z\u002f+folSDDTfPxg3p\u002f9zON8\u002fpcmveMM83z\u002fYlqM8+0DfPzTzEsYbRd8\u002fjSceiyVJ3z8PcXX9GE3fPy4BWYr2UN8\u002ft\u002f2Ymr5U3z\u002fFgJWScVjfP8WYPtIPXN8\u002fdUgUtZlf3z\u002fITQLWD2PfP\u002ftAPP5yZt8\u002f1XvTmMNp3z8H\u002f8sMAm3fP6a3Gb4ucN8\u002fJ3+gDUpz3z9kGzRZVHb ...

# %% [markdown]
# ### Model Calibration
# How to design experiments to determine kinetics?
# In this notebook, we use a simple grid-based experimental approach.
# Recall that
# $k = k_{ref}\cdot\exp{(-\frac{E_a}{R}(\frac{1}{T} - \frac{1}{293.15}))}$, $r_r = k\prod c^n$
# By varying residence time and initial A concentration, we can calibrate $k$ for each temperature
# By varying temperature, we can calibrate the Activation Energy $E_a$

# %%
# Print column names for operation parameters
print("Column names for operation parameters:")
for name_ind in toy_case.operation_name2ind():
    print(name_ind)
# Out:
# Column names for operation parameters:
# ('A_conc', {'param': 'Concentration', 'stream': 'Batch_Feed', 'species': 'A'})
# ('temp', {'param': 'Temperature'})
# ('t_b', {'param': 'Batch_Time'})

# %% [markdown]
# ### Prediction error minimisation
# Assume these data are obtained from experiments. Then, the model is fitted by minimising the prediction error on these operation conditions
# $Error = Mean((c_{measured,B} - c_{predicted,B})^2)$
# The quasi-Newton algorithm `L-BFGS-B` is used to minimise this error
# Find original codes of the `calibrate` method in `cases/toy_case.py` file

# %%
# First, we design grid experiment points and calibrate k_ref at referenced temperature (25 oC)
# Run simulation to mimic experiment data
exp_data1 = {
    "A_conc": [0.25, 0.25, 0.75, 0.75],
    "temp":   [  25,   25,   25,   25],
    "t_b":    [  30,   60,   30,   60],
}
exp_dataset1 = pd.DataFrame(exp_data1)
exp_dataset1 = toy_case.run_dataset(exp_dataset1)

# Define parameter bound for calibration
cal_param_bounds = [
    (
        {
            "param": "Referenced_Reaction_Rate_Constant", 
            "stream": "Batch_Feed", 
            "reaction": "A > B"
        },
        (1e-6, 1e-3)
    )
]

# Calbrate referenced reaction rate constant
calibrated_kref = toy_case.calibrate(cal_param_bounds, exp_dataset1)[0]
print(calibrated_kref)
# Out:
# ({'param': 'Referenced_Reaction_Rate_Constant', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 0.0001)

# %%
# Then, we design grid experiment points for 50 and 75 oC to calibrate activation energy
# Run simulation to mimic experiment data
exp_data2 = {
    "A_conc": [0.25, 0.25, 0.75, 0.75, 0.25, 0.25, 0.75, 0.75],
    "temp":   [  50,   50,   50,   50,   75,   75,   75,   75],
    "t_b":    [  30,   60,   30,   60,   30,   60,   30,   60],
}
exp_dataset2 = pd.DataFrame(exp_data2)
exp_dataset2 = toy_case.run_dataset(exp_dataset2)

# Define parameter bound for calibration
cal_param_bounds = [
    (
        {
            "param": "Referenced_Reaction_Rate_Constant", 
            "stream": "Batch_Feed", 
            "reaction": "A > B"
        },
        (1e-4, 1e-4)
    ), 
    (
        {
            "param": "Activation_Energy", 
            "stream": "Batch_Feed", 
            "reaction": "A > B"
        },
        (20, 100)
    )
]

# Calbrate activation energy
calibrated_params = toy_case.calibrate(cal_param_bounds, exp_dataset2)
for calibrated_param in calibrated_params:
    print(calibrated_param)
# Out:
# ({'param': 'Activation_Energy', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 60.140533)
# ({'param': 'Referenced_Reaction_Rate_Constant', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 0.0001)
