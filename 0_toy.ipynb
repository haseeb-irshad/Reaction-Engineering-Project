# %% [markdown]
# # Toy Case
#
# This case employs a simple reaction `A > B` performed in a batch reactor to introduce the provided modelling environment.
#
# <div><center><img src="https://upload.wikimedia.org/wikipedia/commons/1/15/Batch_reactor_STR.svg" width="150"/></center></div>
#
# The mass balance equation for batch reactor is
# $$\frac{dc}{dt} = r_r$$
# The reaction rate constant of `A > B` follows Arrhenius equation
# $$k = A\cdot\exp{(-\frac{E_a}{RT})}$$
# We reparameterise Arrhenius with reference to 20 oC
# $$k = k_{ref}\cdot\exp{(-\frac{E_a}{R}(\frac{1}{T} - \frac{1}{293.15}))}$$
# The reaction rate follows power law with respect to concentrations of reactants
# $$r_r = k\prod c^n$$

# %%
# import required python libraries
import numpy as np
import pandas as pd
from bayes_opt import BayesianOptimization, acquisition
from plotly.offline import init_notebook_mode

from cases.toy_case import ToyCase

init_notebook_mode(connected=True)

# define phenomenon for the process to define the model
phenos = {
    "Mass accumulation":    "Batch",
    "Flow pattern":         "Well_Mixed",
    "Mass transport":       [],
}

toy_case = ToyCase(phenos, random_seed=42)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %% [markdown]
# #### Parameter Setup
# As modelling parameters are associated with different dimensions (solid/liquid, stream, reaction, species), all parameters are indicated as `(Parameter Name, Solid/Liquid index, Stream index, Reaction index, Species index)` in this provided modelling environment.
# Note that `None` will be applied if the parameter is not associated with that specific dimension.
#
# > **Operation parameters**
# >
# > - ("Temperature", None, None, None, None)     [No dimension related to temperature]
# > - ("Batch_Time", None, None, None, None)      [No dimension related to batch time]
# > - ("Concentration", None, 0, None, 0)         [Concentration of A]
# >
# > **Kinetics parameters**
# > - ("Activation_Energy", None, 0, 0, None)                 [Activation energy is related to stream and reaction dimensions]
# > - ("Referenced_Reaction_Rate_Constant", None, 0, 0, None) [Referenced reaction rate constant is related to stream and reaction dimensions]
#
# #### Unit Setup
#
# Parameter setup can be found in the method `var2unit`
#
# | Parameter                         | Unit   |
# | --------------------------------- | ------ |
# | Referenced_Reaction_Rate_Constant |        |
# | Activation_Energy                 | kJ/mol |
# | Temperature                       | oC     |
# | Concentration                     | mol/L  |
# | Batch_Time                        | min    |

# %% [markdown]
# ### Model Simulation
# - Print model kinetics parameters and operation parameters
# - Set operation condition example and plot the concentration curves against operation time
# - Plot B concentration profiles at varied temperatures
# - Plot B concentration profiles at varied initial A concentrations

# %%
# list of kinetics and operation parameters
toy_case.kinetics_params(), toy_case.operation_params()
# Out:
# ({('Activation_Energy', None, 0, 0, None): 80.0,
#   ('Referenced_Reaction_Rate_Constant', None, 0, 0, None): 0.0001,
#   ('Stoichiometric_Coefficient', None, None, 0, 0): -1,
#   ('Stoichiometric_Coefficient', None, None, 0, 1): 1,
#   ('Partial_Order', None, None, 0, 0): 1},
#  {('Concentration', None, 0, None, 0): None,
#   ('Temperature', None, None, None, None): None,
#   ('Batch_Time', None, None, None, None): None})

# %%
# model simulation and plot concentration profiles
# A concentration   [A] = 1 mol/L
# temperature       T = 50.0 oC
# batch time        t_b = 60.0 min
operation_params = {
    ('Concentration', None, 0, None, 0): 1.0,
    ('Temperature', None, None, None, None): 50.0,
    ('Batch_Time', None, None, None, None): 60.0
}
toy_case.plot_simulation_profiles(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="50e1f174-0e51-4063-b49c-2dcdbdc51d31" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("50e1f174-0e51-4063-b49c-2dcdbdc51d31")) {                    Plotly.newPlot(                        "50e1f174-0e51-4063-b49c-2dcdbdc51d31",                        [{"hovertemplate":"Species=A\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eConcentration (mol\u002fL)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"A","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAzMzMzMzPTPzMzMzMzM+M\u002fzczMzMzM7D8zMzMzMzPzPwAAAAAAAPg\u002fzczMzMzM\u002fD\...\\...\u002fNMQJqZmZmZGU1AAAAAAABATUBmZmZmZmZNQM3MzMzMjE1AMzMzMzOzTUCamZmZmdlNQAAAAAAAAE5A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA8D9miJqIT8\u002fuP9nmLvnzqe0\u002fJQtco4GP7D\u002fuQr\u002fAkH\u002frP7Y9Eei9eeo\u002f0sI6zKd96T88wiXW8IroP9vmsZk\u002foec\u002fgZa01T7A5j+BsRpnneflP85ozCQJF+U\u002fXVZEBTNO5D\u002fXY6wT0ozjP\u002fmOp\u002fig0uI\u002fpulR+l0f4j\u002fZmUD8ynLhP6CWJ5GozOA\u002fA2aSlrIs4D9sUCBCXCXfPzpIkjjG\u002fN0\u002flVreLTjf3D\u002f8R3uFTMzbPw7nicigw9o\u002f\u002fF7Kb8vE2T+CSSRHbc\u002fYP8Suosss49c\u002fszOfq7T\u002f1j8OGsLGsyTWP7BMEd\u002fcUdU\u002flAOYt92G1D+J2OKkaMPTP1ZR31I2B9M\u002f3aVUwAJS0j8RwOM+jaPRPwA8B3OY+9A\u002frT2F3uFZ0D\u002f0JxcSSXzPP5HZwuROUM4\u002fCjfWCGkvzT\u002fost8QMRnMP2CLM05GDcs\u002fUMrr0E0Lyj9BRehn8hLJP2ydzqDkI8g\u002fsz8KyNo9xz\u002fcwx7okGDGP89alJKci8U\u002fHZgy0Iq+xD\u002fCPHYNEPnDPz9cyHXkOsM\u002fpFx+88ODwj+H9tkvbtPBPwg1CZOmKcE\u002f03UmRDSGwD800nBSxNG\u002fPzsjZM79or4\u002fSObmZbl\u002fvT9t03znYme8P1n2u\u002fVpWbs\u002fKKKSBGpVuj97reV6A1u5P2NykLLbabg\u002fcM5k+JyBtz+qIiuM9qG2P5NToqCcyrU\u002fJ8l\u002fW0j7tD\u002fabm\u002fVtzO0PzvKy1Ktc7M\u002fVdj6M8e6sj\u002fzyi84rgiyP+wPJ64hXbE\u002fW1qFXeS3sD+aoteGvBiwP4RMJsfn\u002fq4\u002fVdAqTK\u002fXrT\u002fYYEjzcLusP70Y2wTVqas\u002fMp0Pu4qiqj\u002f7cA1MRaWpP0LUp2Zzsag\u002fGVnlpJ\u002fGpz859nyQdOSmP4XughShCqY\u002fDtFofdg4pT8Kef140m6kP+ANbRZLrKM\u002fHwNBxgLxoj99GGBavjyiP+FZDgZHj6E\u002fUUltO2fooD\u002f0GuKwvkegPyChFT0IWp8\u002fRFHHKf0vnj\u002fde3T17xCdP\u002fYOWxp6\u002fJs\u002fJ7Fbvzrymj+Hwfm31vGZP8JXW4T4+pg\u002f\u002fUNJUVANmD\u002fwDi\u002f4kyiXP8EkO255TJY\u002fUN9Z5oV4lT+b7aU5X6yUPwuePWe755M\u002fY9NoWFQqkz+9BJng53OSP4k9ab03xJE\u002flh2elgkbkT8E2SX+JniQP6BwMOC6to8\u002fmzBtpfyIjj+B5Z9KsWaNP8r69a0pT4w\u002feYkxR\u002fBBiz+DkX5xoz6KP+kkP5bmRIk\u002ft2cLLWJUiD8FkLG7w2yHP\u002fflNda9jYY\u002ftsPSHgi3hT+AlfhFX+iEP5TZTQqFIYQ\u002fgmHJQzVigz+jrt6i\u002fKmCP0bT\u002ff6P+IE\u002f4Xbsbq5NgT+K+AlUGqmAP\u002fxuT1qZCoA\u002fIVGf8Ojjfj+FVm7e7719P11pmJXmonw\u002fJ3TdwnKSez+e0DCoQIx6Pz30og3yj3k\u002f3QLX+\u002fSceD+muitz6rJ3P3Q1V7F90XY\u002fX3qWcF74dT\u002fAfa3nQCd1Py0h58ndXXQ\u002ffjMVR\u002fKbcz\u002fKcJALQOFyP2OCOECNLXI\u002f3P5ziqSAcT8EWVL3RNpwP9SzA7cKOnA\u002f7GQZnXA\u002fbz\u002fErePYKxZuPwixHVvd92w\u002fbUgtOiHkaz+VuCZpmdpqPwOxzLft2mk\u002fHkyQ0svkaD80D5FC5\u002fdnP3nqnG35E2c\u002ftVwPeqc4Zj9ZVLecb2VlP2qetfkBmmQ\u002fXYSuiBTWYz\u002f3D6AUYRljP0kL4julY2I\u002fvAAmcKK0YT8CO3f2HQxhPyTFOufgaWA\u002f7tReXHCbXz9BbdsU6W5ePxkA6UmuTV0\u002f1MhsUx03XD+5dSUAzypbP0lAXlliKFo\u002f1\u002feJkXsvWT+BAUMExD9YPzhYSzbqWFc\u002fvIyM1aF6Vj+dxRe5o6RVPzm\u002fJeGt1lQ\u002fv8sWd4MQVD93XEXVy1FTP\u002f9rrXIcmlI\u002fhQdk8DHpUT9320eBzD5RP9i1xryvmlA\u002fdQy7PUX5Tz ...

# %%
# B concentration profiles under vared temperatures
# set temperature to a list of values: 25.0, 50.0, 75.0, 100.0
operation_params = {
    ('Concentration', None, 0, None, 0): 1.0,
    ('Temperature', None, None, None, None): [25.0, 50.0, 75.0, 100.0],
    ('Batch_Time', None, None, None, None): 60.0
}
toy_case.plot_product_profile_with_temperatures(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="477cbede-5f68-4ae4-9042-5c25e7aaeb1e" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("477cbede-5f68-4ae4-9042-5c25e7aaeb1e")) {                    Plotly.newPlot(                        "477cbede-5f68-4ae4-9042-5c25e7aaeb1e",                        [{"hovertemplate":"Temperature (oC)=25.0\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eB concentration (mol\u002fL)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"25.0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"25.0","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAzMzMzMzPTPzMzMzMzM+M\u002fzczMzMzM7D8zMzMzMzPzPwAAAAAAAPg\u002fzczMzMzM\u002fD\...\\...\u002fNMQJqZmZmZGU1AAAAAAABATUBmZmZmZmZNQM3MzMzMjE1AMzMzMzOzTUCamZmZmdlNQAAAAAAAAE5A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACcKM8fnodpPzd8uQxvfXk\u002fbswyC3QWgz\u002fiRoNIIGmJP1yFiinAto8\u002fIQPT9Kv\u002fkj8YOwTidSGWP+RA8vm\u002fQJk\u002f0mo2WoxdnD80D2og3XefPyxCEzXaR6E\u002fRpCCKorSoj8RnU9\u002f\u002f1ukPw1qWR075KU\u002fSHdCwz1rpz\u002fApEFqCPGoP0KHBg2cdao\u002fp7NApvn4qz++vp8wInutP1w906YW\u002fK4\u002fKWLFAew9sD889LqgM\u002f2wP0wfoq3iu7E\u002f0R3NoPl5sj8YvwrneDezPzIM7Phg9LM\u002f5RTkT7KwtD\u002f66GVlbWy1PzaY5LKSJ7Y\u002fYzLTsSLitj9Ex6TbHZy3P6NmzKmEVbg\u002fRiC9lVcOuT\u002fKO7sVl8a5P1zR45JDfro\u002fn1AkgV01uz8JOClW5eu7PwwGn4fbobw\u002fJDkyi0BXvT+\u002fT4\u002fWFAy+P1fIYt9YwL4\u002fYCFZGw10vz+nbA8AmRPAP\u002fxx2P\u002fjbMA\u002fe2EOuefFwD\u002fNPYVipB7BP4uj7zUad8E\u002fpfDNbEnPwT90RG5AMifCP6p\u002f7OnUfsI\u002fW0QyojHWwj\u002f69fahSC3DP1a5vyEahMM\u002fpXTfWabawz95z3aC7TDEP8EydNPvhsQ\u002f0MiThK3cxD9TfV\u002fNJjLFP1r9LuVbh8U\u002fV7cnA03cxT8Y2zxe+jDGP8tZLy1khcY\u002f\u002fuWNporZxj+f87QAbi3HP\u002fi3znEOgcc\u002fuCnTL2zUxz\u002frAIhwhyfIP\u002f+2gGlgesg\u002fu4YeUPfMyD9LbJBZTB\u002fJPzsl07pfcck\u002fdDCxqDHDyT8+zsJXwhTKP0EAbvwRZso\u002fi4nmyiC3yj997i337gfLP+J0E7V8WMs\u002f4SM0OMqoyz8BxPqz1\u002fjLPyjfn1ulSMw\u002fmcApYjOYzD\u002f9dGz6gefMP1fKCVeRNs0\u002fDFBxqmGFzT\u002fdVuAm89PNP\u002fLwYf5FIs4\u002fy\u002fHOYlpwzj9K7s2FML7OP7Q805jIC88\u002fp\u002fQgzSJZzz8n78ZTP6bPP5HGol0e888\u002fVuuvDeAf0D9HnrteEkbQP1\u002frFzombNA\u002fjSLPtxuS0D9udNLv8rfQP1Py+fmr3dA\u002fOo4E7kYD0T\u002fRGpjjwyjRP3dLQfIiTtE\u002fObRzMWRz0T\u002fYyYm4h5jRP73hxJ6NvdE\u002fCDJN+3Xi0T+H0THlQAfSP7S3aHPuK9I\u002fvbzOvH5Q0j9+mSfY8XTSP4bnHdxHmdI\u002fDSFD34C90j8BoQ\u002f4nOHSP\u002f6i4jycBdM\u002fTUMCxH4p0z\u002frfpujRE3TP4EzwvHtcNM\u002fbh9xxHqU0z+34Ykx67fTPxf61E4\u002f29M\u002f+8gBMnf+0z94UO78kiHUP5LKJNOSRNQ\u002fU3EOy3Zn1D\u002f2Hv36PorUP0PjLHnrrNQ\u002fgwPEW3zP1D+I+tK48fHUP6p4VKZLFNU\u002fyGMtOoo21T9M1yyKrVjVPyAkDKy1etU\u002fudButaKc1T8UmeK7dL7VP7Ru39Qr4NU\u002foXjHFcgB1j9tE+eTSSPWPy3RdGSwRNY\u002fgnmRnPxl1j+RCUhRLofWPwS0jZdFqNY\u002fEeFBhELJ1j9yLi4sJerWP2dvBqTtCtc\u002fuKxoAJwr1z+2JN1VMEzXPzZL1riqbNc\u002flsmwPQuN1z+5frP4Ua3XPwp\u002fD\u002f5+zdc\u002ffBTgYZLt1z+Ivio4jA3YPy4y35RsLdg\u002f81nXizNN2D\u002fnVdcw4WzYP597jZd1jNg\u002fNlaS0\u002fCr2D9Ppmj4UsvYPxNifRmc6tg\u002fNrUnSswJ2T\u002fsAKmd4yjZP\u002fTbLCfiR9k\u002flhLJ+cdm2T+dpn0olYXZP13PNMZJpNk\u002fsPnC5eXC2T\u002f5x+aZaeHZPx8SSfXU\u002f9k\u002fk+V8Cige2j9Jhf\u002frYjzaP8NpOKyFWto\u002f\u002f0B5XZB42j+O7v0Rg5baP4CL7NtdtNo\u002fbWZVzSDS2j94AzP4y+\u002faP0ccam5fDds\u002fCKDJQdsq2z9wswqEP0jbP7qw0EaMZds\u002frSepm8GC2z+R3QuU35\u002fbPzTNWkHmvNs\u002f8ybitNXZ2z+rUNj ...

# %%
# B concentration profiles under vared A concentrations
# set A concentration to a list of values: [0.5, 1.0, 1.5, 2.0]
operation_params = {
    ('Concentration', None, 0, None, 0): [0.5, 1.0, 1.5, 2.0],
    ('Temperature', None, None, None, None): 50.0,
    ('Batch_Time', None, None, None, None): 60.0
}
toy_case.plot_product_profile_with_A_concs(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="d59f49fe-3544-4ec0-b5cd-ad02313ad0a4" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d59f49fe-3544-4ec0-b5cd-ad02313ad0a4")) {                    Plotly.newPlot(                        "d59f49fe-3544-4ec0-b5cd-ad02313ad0a4",                        [{"hovertemplate":"A concentration (mol\u002fL)=0.5\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eB concentration (mol\u002fL)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.5","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0.5","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAzMzMzMzPTPzMzMzMzM+M\u002fzczMzMzM7D8zMzMzMzPzPwAAAAAAAPg\u002fzczMzMzM\u002fD\...\\...\u002fNMQJqZmZmZGU1AAAAAAABATUBmZmZmZmZNQM3MzMzMjE1AMzMzMzOzTUCamZmZmdlNQAAAAAAAAE5A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAAASOIMkBAuTP+7SChxbsKI\u002fxDUosOyDqz\u002f5zODBuQGyP9o+vOQHGbY\u002fedo6318Juj8K0SbANNS9P7HVy814vcA\u002fD3ifknh\u002fwj+7NpLWvjDEP54c04\u002fo0cU\u002fOCubOItjxz+mFf4kQ+bIP4vFlUyiWso\u002fbwStUy\u002fByz8YDyzpaRrNP4KVmMbKZs4\u002f6roVsMOmzz9gC56dYm3QPxsWo2epAdE\u002fbRrADW6Q0T\u002fCoyyz5BnSP9BeFww\u002fntI\u002fphmmXawd0z+Zw\u002fV9WZjTP31yE1l0DtQ\u002f6ytibCyA1D+dlnR8q+3UP6BlrFgZV9U\u002fnloX5pu81T\u002fYRW8fVx7WP1f2uzdtfNY\u002fRElpSgPX1j+sLrVjPC7XPz4jJlQ4gtc\u002fP4CQbBXT1z+UexZ+8CDYP7cnKNrka9g\u002fBHcgkw202D9JWvIAi\u002fnYP5ddtqd3PNk\u002fpxHJxet82T+y2rpT\u002frrZP3TwTwTF9tk\u002fM16ARFQw2j+0Ang7v2faP0GQlsoXndo\u002fp4xvjW7Q2j88UcrZ0gHbP22z42BWMds\u002fl0arHhZf2z8n+lhHJIvbP9SrbPyQtds\u002fiIxejWve2z9pIJ93wgXcP9E+l2ajK9w\u002fURKoMxtQ3D+zGCvmNXPcP\u002fcicrP+lNw\u002fV1XH\u002fn+13D8OxTtfxtTcPyi9sUXk8tw\u002f0ix1XOUP3T8bqx1Z1CvdP4iqimW7Rt0\u002fBXnjH6Rg3T\u002fyP5eal3ndPxoEXVyekd0\u002fuqUzYMCo3T984GEVBb\u002fdP3dLdl9z1N0\u002f+CO68xPp3T\u002faNVgn8vzdPxjEplIVEN4\u002fox7xUoQi3j+IJ5ajRTTeP\u002fhSCF5fRd4\u002fO6fNOddV3j+\u002fvH+MsmXePw++y0n2dN4\u002f1WdyA6eD3j\u002fbCEjpyJHeP4u+l2lin94\u002f8VKLbnus3j8EQ2zGGLnePyWZJv4+xd4\u002f4iQcZfLQ3j\u002f3eiQNN9zeP0\u002f1jMoQ594\u002f\u002f7IYNIPx3j9NmACjkfveP6hO8zI\u002fBd8\u002fiHBzwo4O3z+Fc6ndhBffPysq80gmIN8\u002fVN7+M3Yo3z8Jn1umdzDfP4FAeX8tON8\u002fJlyodpo\u002f3z+NUBobwUbfP39B4dOjTd8\u002f8hfw30RU3z8KghpWplrfP0YXaynKYN8\u002fXElNcLNm3z8PBHEDZWzfPxl97PTgcd8\u002fb+kkOyl33z86fc6wP3zfP95r7BQmgd8\u002f8efQCt6F3z9GIx0aaYrfP+ROwa7Ijt8\u002fC5v8GP6S3z88LlKYCpffPzqUlXDwmt8\u002fDYrze7Ge3z+9U14YT6LfP4Cf8ZHKpd8\u002fvYXyIiWp3z8Mic\u002fzX6zfPzuWIBt8r98\u002fQQSnnXqy3z9NlE1uXLXfP71xKG4iuN8\u002fm0LFes263z+Zi6UcX73fPzK0RHrYv98\u002fH9X4ezrC3z+RvG3+hcTfPznupNK7xt8\u002fO6P1vdzI3z8+ygx66crfP2EH7bTizN8\u002fPLTuEMnO3z\u002fj378kndDfP6EzKIpf0t8\u002fda8eQRHU3z8FPh3\u002fstXfP9pexltF198\u002fXdfH5sjY3z\u002fRstonPtrfP1xCw56l298\u002f\u002fhxRw\u002f\u002fc3z+aH18FTd7fP+1s08yN398\u002flW2fecLg3z\u002fUV6Z06+HfP7SxgHAJ498\u002famdH4Rzk3z\u002fOA+MqJuXfP41nC6wl5t8\u002fJ8lHvhvn3z\u002fxtO61COjfPxMNJuLs6N8\u002fiAnjjMjp3z8fOOr6m+rfP3h8z2tn698\u002fyumWKSvs3z+Iwoup5+zfP+ZcmjWd7d8\u002fOtbzD0zu3z9mcWN39O7fP9iWTqeW798\u002fj9S01zLw3z8X3i89yfDfP4eM8wha8d8\u002fhd7NaOXx3z9J+CaHa\u002fLfP+2VDZjs8t8\u002fWRrJ5Wjz3z+szVSf4PPfP8qZA\u002fBT9N8\u002f7h3dAMP03z+wrp34LfXfP\u002f9VtvuU9d8\u002fItNMLPj13z+7mjuqV\u002fbfP8fWEZOz9t8\u002fmmYTAgz33z89cl0cYfffP4K\u002f6hKz998\u002fIZ0ZBAL43z+2yG0MTvjfP70v6UaX+N8\u002fk+8Lzd343z97VdS2IfnfP5ne ...

# %% [markdown]
# ### Model Calibration
# How to design experiments to determine kinetics?
# In this notebook, we use a simple grid-based experimental approach.
# Recall that
# $k = k_{ref}\cdot\exp{(-\frac{E_a}{R}(\frac{1}{T} - \frac{1}{293.15}))}$, $r_r = k\prod c^n$
# By varying residence time and initial A concentration, we can calibrate $k$ for each temperature
# By varying temperature, we can calibrate the Activation Energy $E_a$

# %%
# print short names for operation parameters
toy_case.operation_name2ind()
# Out:
# {'A_conc': ('Concentration', None, 0, None, 0),
#  'temp': ('Temperature', None, None, None, None),
#  't_b': ('Batch_Time', None, None, None, None)}

# %%
# set up grid experiment data points
exp_data = {
    "A_conc": [0.25, 0.25, 0.25, 0.25, 0.75, 0.75, 0.75, 0.75],
    "temp":   [  25,   25,   50,   50,   25,   25,   50,   50],
    "t_b":    [  30,   60,   30,   60,   30,   60,   30,   60],
}
# create tabular dataset
exp_dataset = pd.DataFrame(exp_data)
# run simulation
exp_dataset = toy_case.run_dataset(exp_dataset)
exp_dataset
# Out:
#    A_conc  temp  t_b  outlet_B_conc
# 0    0.25    25   30       0.067028
# 1    0.25    25   60       0.116086
# 2    0.25    50   30       0.244347
# 3    0.25    50   60       0.249872
# 4    0.75    25   30       0.201084
# 5    0.75    25   60       0.348266
# 6    0.75    50   30       0.733037
# 7    0.75    50   60       0.749616

# %% [markdown]
# ### Prediction error minimisation
# Assume these data are obtained from experiments. Then, the model is fitted by minimising the prediction error on these operation conditions
# $Error = Mean((c_{measured,B} - c_{predicted,B})^2)$
# The quasi-Newton algorithm `L-BFGS-B` is used to minimise this error
# Find original codes of the `calibrate` method in `cases/toy_case.py` file

# %%
# Run the `calibrate` method
# Fitted activation energy and referenced reaction rate constant are close to the actual values
cal_param_bounds = {
    ("Activation_Energy", None, 0, 0, None):                    (40, 120), # kJ/mol
    ("Referenced_Reaction_Rate_Constant", None, 0, 0, None):    (1e-6, 1e-3),
}
toy_case.calibrate(cal_param_bounds, exp_dataset)
# Out:
# {('Activation_Energy', None, 0, 0, None): 79.41151,
#  ('Referenced_Reaction_Rate_Constant', None, 0, 0, None): 0.000101}

# %%
# print the ground-truth kinetics
toy_case.kinetics_params()
# Out:
# {('Activation_Energy', None, 0, 0, None): 80.0,
#  ('Referenced_Reaction_Rate_Constant', None, 0, 0, None): 0.0001,
#  ('Stoichiometric_Coefficient', None, None, 0, 0): -1,
#  ('Stoichiometric_Coefficient', None, None, 0, 1): 1,
#  ('Partial_Order', None, None, 0, 0): 1}
