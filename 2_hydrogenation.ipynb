# %%
# install required packages in jupyter lab
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: bayesian-optimization==3.1.0 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: ipykernel==7.0.0 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 2)) (7.0.0)
# Requirement already satisfied: ipywidgets==8.1.7 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 3)) (8.1.7)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 4)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.8.1 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 5)) (5.8.1)
# Requirement already satisfied: jupyterlab_widgets==3.0.15 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 6)) (3.0.15)
# Requirement already satisfied: numpy==2.3.3 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 7)) (2.3.3)
# Requirement already satisfied: pandas==2.3.3 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 8)) (2.3.3)
# Requirement already satisfied: plotly==6.3.1 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 9)) (6.3.1)
# Requirement already satisfied: scikit-learn==1.7.2 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 10)) (1.7.2)
# Requirement already satisfied: scipy==1.16.2 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 11)) (1.16.2)
# Requirement already satisfied: nbformat==5.10.4 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 12)) (5.10.4)
# Requirement already satisfied: colorama>=0.4.6 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from bayesian-optimization==3.1.0->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (9.7.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0->-r requirements.txt (line 2)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets==8.1.7->-r requirements.txt (line 3)) (4.0.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from jupyter_client==8.6.3->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from jupyter_core==5.8.1->-r requirements.txt (line 5)) (4.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from jupyter_core==5.8.1->-r requirements.txt (line 5)) (311)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from pandas==2.3.3->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from pandas==2.3.3->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from plotly==6.3.1->-r requirements.txt (line 9)) (2.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn==1.7.2->-r requirements.txt (line 10)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn==1.7.2->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from nbformat==5.10.4->-r requirements.txt (line 12)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from nbformat==5.10.4->-r requirements.txt (line 12)) (4.25.1)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat==5.10.4->-r requirements.txt (line 12)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat==5.10.4->-r requirements.txt (line 12)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat==5.10.4->-r requirements.txt (line 12)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell xps\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat==5.10.4->-r requirements.txt (line 12)) (0.29.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->jupyter_client==8.6.3->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\dell xps\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.0.0->-r requirements.txt (line 2)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Hydrogenation Case
#
# <!-- <div><img src="cases/hydrogenation_process_scheme.jpg" width="600"/></div> -->
# ![](./cases/hydrogenation_process_scheme.png)
#
# This case models a chemical process in which R-di-yne (RDY) undergoes hydrogenation to produce R-di-ethyl (RDEt).
# During the process, RDY and hydrogen gas are dissolved in a mixed liquid of water and an unknown solvent, with
# agitation applied to promote mass transfer. A cooling jacket is used to remove the heat generated by the exothermic
# hydrogenation reactions.
# The di-yne group of RDY is progressively hydrogenated by the catalyst (cat-H) through a sequence of intermediates —
# RDY ⟶ RYE ⟶ RYA ⟶ REA ⟶ RDEt. In addition, side reactions leading to dimer formation may occur during the process.
#
# The reaction scheme is like:
# ![](./cases/hydrogenation_reaction_scheme.png)
#
# Reactions:
# - H2 + cat2 ⟶ 2 cat-H
# - 2 cat-H ⟶ H2 + cat2
# - RDY + 2 cat-H ⟶ RYE + cat2
# - RYE + 2 cat-H ⟶ RYA + cat2
# - RYA + 2 cat-H ⟶ REA + cat2
# - REA + 2 cat-H ⟶ RDEt + cat2
# - RDEt + catX ⟶ catX-RDEt
# - catX-RDEt ⟶ RDEt + catX
# - RYE + catX-RDEt ⟶ dimer + catX
# - REA + catX-RDEt ⟶ 2 H2 + dimer + catX
#
# Mass Transfer:
# The gas-liquid and solid-liquid coefficients are correlated to agitation speed as $k_La = DN^\alpha$ and $k_Sa = DN^\alpha$, respectively
#
# In this notebook, we go through model simulation and identify the rate-limiting step of the hydrogenation reaction.
# Then, sensitivity analysis is applied to identify parameters for model calibration.
# Finally, we run model calibration with different mass transport behaviours for model identification.

# %%
# import required python libraries
import pandas as pd
from plotly.offline import init_notebook_mode
init_notebook_mode(connected = True)

from cases.hydrogenation_agitation import Hydrogenation

# Define phenomenon for the process to define the model
# RDY saturated concentration is fitted with RDEt concentration
# Supported phenomenon options:
# "Mass transport":
#       []
#       ["Gas-Liquid_Mass_Transfer"]
#       ["Solid-Liquid_Mass_Transfer"]
#       ["Gas-Liquid_Mass_Transfer", "Solid-Liquid_Mass_Transfer"],
# if "Gas-Liquid_Mass_Transfer" occurs, "Gas_Dissolution_Saturated_Concentration" can be "Henry's_Law" or "Constant" 
# if "Solid-Liquid_Mass_Transfer" occurs, "Solid_Dissolution_Saturated_Concentration" can be "Fitted" or "Constant" 
# RDY dissolution saturated concentration is found dependent on RDEt concentration, a relationship has been fitted and 
# included in the `hydrogenation.py` file for modelling
phenos = {
    "Mass accumulation":    "Batch",
    "Flow pattern":         "Well_Mixed",
    "Mass transport":       ["Gas-Liquid_Mass_Transfer", "Solid-Liquid_Mass_Transfer"],
    "param law":            {
        "Gas_Dissolution_Saturated_Concentration": "Henry's_Law",
        "Solid_Dissolution_Saturated_Concentration": "Fitted", 
    },
}

hydrogenation = Hydrogenation(phenos, random_seed = 42)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %% [markdown]
# ### Model Simulation and Rate-limiting Step analysis
# In this section, we run hydrogenation simulation with guessed kinetic parameters to visualise concentration profiles of reactants, intermediates, and products.
# Rate-limiting step is analysed by plotting intermediate mass profiles and rates of reaction and mass transport, which is further confirmed by sensitivity analysis.

# %%
# list operation parameters
# during experiments, masses of used water, solvent, and catalysts are fixed
for operation_param in hydrogenation.operation_params():
    print(operation_param)
# Out:
# ({'param': 'Initial_Mass', 'stream': 'Batch_Feed', 'species': 'water'}, 0.2574)
# ({'param': 'Initial_Mass', 'stream': 'Batch_Feed', 'species': 'solvent'}, 0.194)
# ({'param': 'Initial_Mass', 'stream': 'Batch_Feed', 'species': 'cat2'}, 0.00235)
# ({'param': 'Initial_Mass', 'stream': 'Batch_Feed', 'species': 'catX'}, 0.00235)
# ({'param': 'Mass_Gas_Fraction', 'gas': 'Gas_Flow', 'species': 'H2'}, 1.0)
# ({'param': 'Initial_Mass_Solid', 'solid': 'Solid_Feedstock', 'species': 'RDY'}, None)
# ({'param': 'Temperature'}, None)
# ({'param': 'Pressure'}, None)
# ({'param': 'Agitation'}, None)
# ({'param': 'Batch_Time'}, None)

# %%
# model simulation and concentration profile plot
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444),
    ({"param": "Temperature"}, 20),
    ({"param": "Pressure"},     4),
    ({"param": "Agitation"}, 1200),
    ({"param": "Batch_Time"}, 309),
]
hydrogenation.plot_simulation_profiles(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444),
    ({"param": "Temperature"}, 20),
    ({"param": "Pressure"},     4),
    ({"param": "Agitation"}, 1200),
    ({"param": "Batch_Time"}, 309),
]
steps = [
    "H2 + cat2 ⟶ 2 cat-H",
    "2 cat-H ⟶ H2 + cat2",
    "RDY + 2 cat-H ⟶ RYE + cat2",
    "RYE + 2 cat-H ⟶ RYA + cat2",
    "RYA + 2 cat-H ⟶ REA + cat2",
    "REA + 2 cat-H ⟶ RDEt + cat2",
    "RDEt + catX ⟶ catX-RDEt",
    "catX-RDEt ⟶ RDEt + catX",
    "RYE + catX-RDEt ⟶ dimer + catX",
    "REA + catX-RDEt ⟶ 2 H2 + dimer + catX",
    "H2 dissolution", 
    "RDY dissolution"
]
hydrogenation.plot_simulation_rates(steps, operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="0a733d2f-fd10-4a23-b4be-2efd98a64722" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0a733d2f-fd10-4a23-b4be-2efd98a64722")) {                    Plotly.newPlot(                        "0a733d2f-fd10-4a23-b4be-2efd98a64722",                        [{"hovertemplate":"Reaction\u002fMass transport=H2 + cat2 \u27f6 2 cat-H\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eRate (mol\u002fL s)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 + cat2 \u27f6 2 cat-H","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"H2 + cat2 \u27f6 2 cat-H","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAC5HoXrUbj4P7kehetRuAhAC9ejcD2KEkC5HoXrUbgYQGZmZmZm5h5AC9ejcD2KIkDhehSuR6ElQLkehetRuChAkML1KFzPK0BmZmZmZuYuQB+F61G4\u002fjBAC9ejcD2KMkD2KFyPwhU0QOF6FK5HoTVAzczMzMwsN0C5HoXrUbg4QKRwPQrXQzpAkML1KFzPO0B7FK5H4Vo9QGZmZmZm5j5AKVyPwvU4QEAfhetRuP5AQBSuR+F6xEFAC9ejcD2KQkAAAAAAAFBDQPYoXI\u002fCFURA7FG4HoXbREDhehSuR6FFQNejcD0KZ0ZAzczMzMwsR0DD9Shcj\u002fJHQLkehetRuEhArkfhehR+SUCkcD0K10NKQJqZmZmZCUtAkML1KFzPS0CF61G4HpVMQHsUrkfhWk1AcT0K16MgTkBmZmZmZuZOQF2PwvUorE9AKVyPwvU4UECkcD0K15tQQB+F61G4\u002flBAmpmZmZlhUUAUrkfhesRRQJDC9ShcJ1JAC9ejcD2KUkCF61G4Hu1SQAAAAAAAUFNAexSuR+GyU0D2KFyPwhVUQHE9CtejeFRA7FG4HoXbVEBmZmZmZj5VQOF6FK5HoVVAXY\u002fC9SgEVkDXo3A9CmdWQFK4HoXryVZAzczMzMwsV0BH4XoUro9XQMP1KFyP8ldAPgrXo3BVWEC5HoXrUbhYQDMzMzMzG1lArkfhehR+WUAqXI\u002fC9eBZQKRwPQrXQ1pAH4XrUbimWkCamZmZmQlbQBSuR+F6bFtAkML1KFzPW0AL16NwPTJcQIXrUbgelVxAAAAAAAD4XEB7FK5H4VpdQPYoXI\u002fCvV1AcT0K16MgXkDsUbgehYNeQGZmZmZm5l5A4XoUrkdJX0Bdj8L1KKxfQOxRuB6FB2BAK
CRuPP2UFmPoSFI8\u002fd4WsXSENjz+abVV0NAaPP3Pv+Y1M\u002f44\u002feFokw2n4jj\u002f8zX09jPGOPxxH7yO06o4\u002fEv5rmOHjjj9fbJa3FN2OP+KN9p9N1o4\u002fmuGtcYzPjj80GZRG0ciOPxELbTgcwo4\u002fJdmeX227jj8j9ZnSxLSOP8e8c6Qiro4\u002frRMW6Ianjj9VYrKu8aCOP0MYOw5jmo4\u002fFTDVFtuTjj9xpsvZWY2OP0JJN2Xfho4\u002fPuupyWuAjj9\u002fEQMW\u002f3mOP6kqWlaZc44\u002fdVFImDptjj9 ...

# %%
# Plot only rates of reactions from RDY to RDEt and RDY dissolution rate
# note that there's rate-limiting step in the series of hydrogenation reaction based on the overlapped rate curves
# RDY and RYE accumulate rapidly and then decay slowly
# if "RDY dissolution" is the rate-limiting step, there will be no RDY and RYA mass accumulation
# if "RYA + 2 cat-H ⟶ REA + cat2" is the rate-limiting step, RYA will accumulate which is not the case
# Therefore, "RDY + 2 cat-H ⟶ RYE + cat2" is the rate-limiting step, and RDY concentration rises close
# to the saturated concentration to slow down the solid RDY consumption rate
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444),
    ({"param": "Temperature"}, 20),
    ({"param": "Pressure"},     4),
    ({"param": "Agitation"}, 1200),
    ({"param": "Batch_Time"}, 309),
]
steps = [
    "RDY + 2 cat-H ⟶ RYE + cat2",
    "RYE + 2 cat-H ⟶ RYA + cat2",
    "RYA + 2 cat-H ⟶ REA + cat2",
    "REA + 2 cat-H ⟶ RDEt + cat2",
    "RDY dissolution"
]
hydrogenation.plot_simulation_rates(steps, operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="cbe02b21-0e38-41be-97c0-16db4c564d44" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cbe02b21-0e38-41be-97c0-16db4c564d44")) {                    Plotly.newPlot(                        "cbe02b21-0e38-41be-97c0-16db4c564d44",                        [{"hovertemplate":"Reaction\u002fMass transport=RDY + 2 cat-H \u27f6 RYE + cat2\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eRate (mol\u002fL s)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RDY + 2 cat-H \u27f6 RYE + cat2","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RDY + 2 cat-H \u27f6 RYE + cat2","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAC5HoXrUbj4P7kehetRuAhAC9ejcD2KEkC5HoXrUbgYQGZmZmZm5h5AC9ejcD2KIkDhehSuR6ElQLkehetRuChAkML1KFzPK0BmZmZmZuYuQB+F61G4\u002fjBAC9ejcD2KMkD2KFyPwhU0QOF6FK5HoTVAzczMzMwsN0C5HoXrUbg4QKRwPQrXQzpAkML1KFzPO0B7FK5H4Vo9QGZmZmZm5j5AKVyPwvU4QEAfhetRuP5AQBSuR+F6xEFAC9ejcD2KQkAAAAAAAFBDQPYoXI\u002fCFURA7FG4HoXbREDhehSuR6FFQNejcD0KZ0ZAzczMzMwsR0DD9Shcj\u002fJHQLkehetRuEhArkfhehR+SUCkcD0K10NKQJqZmZmZCUtAkML1KFzPS0CF61G4HpVMQHsUrkfhWk1AcT0K16MgTkBmZmZmZuZOQF2PwvUorE9AKVyPwvU4UECkcD0K15t
5OCMjFXJHj8QV1Bt2XMeP3Dqm75pIB4\u002fFqHO4PbOHT8wNxHfcn8dP64sSxfNMR0\u002f0s8WP+7lHD+0dCZxyJscP\u002fLi6WdKUxw\u002fEpeYWGMMHD\u002fa0OcKA8cbP5Z8a2MXgxs\u002f4GrzR5BAGz+cx6A4fP8aP87jHND6vxo\u002fFjtelXqBGj8gLWkYVkQaP8y+lD1iCBo\u002foMPT9pzNGT9sLldX+5MZP\u002fDtNWlzWxk\u002fI8oIf\u002fwjGT\u002fOnWgbju0YP2BfxSYguBg\u002fMIzWy6qDGD91s9hjJlAYP9IKPJCLHRg\u002fV89nl9PrFz+s4Zcg+LoXP5JRL5fyihc\u002ftkUKLbxbFz++FIeVTy0XP6uVNMin\u002fxY\u002feVJL3L3SFj\u002f0Ew6fjKYWP9oVgg4PexY\u002fbHStw0BQFj\u002fLBxsWHSYWPx6PwNae\u002fBU\u002fpu3Nt8HTFT8pmmNmgasVP9JCD73ZgxU\u002falKbr8ZcFT8rSpNeRDYVPweVHw5PEBU\u002fzE1NGOPqFD+qWI3r\u002fMUUP8geByiZoRQ\u002fXUwVYLR9FD\u002fYv2JeS1oUP\u002fgaPABbNxQ\u002feKSvPeAUFD818KUm2PITP4cQOuY\u002f0RM\u002fIzcQwBSwEz+uaLoMVI8TP9k+yQn7bhM\u002fDoEfLgdPEz9NYkXvdS8TP5kGsM9EEBM\u0 ...

# %%
# plot sensitivity analysis results
# we increase some parameters to 1.5 times of their values and visualise their influences on output
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444),
    ({"param": "Temperature"}, 20),
    ({"param": "Pressure"},     4),
    ({"param": "Agitation"}, 1200),
    ({"param": "Batch_Time"}, 309),
]
varied_mechanistic_params = {
    "original": None,
    "H2 dissolution": {
        "param": "Gas-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
        "gas": "Gas_Flow", 
        "stream": "Batch_Feed", 
        "species": "H2"
    },
    "RDY dissolution": {
        "param": "Solid-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
        "solid": "Solid_Feedstock", 
        "stream": "Batch_Feed", 
        "species": "RDY"
    },
    "RDY hydrogenation": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RDY + 2 cat-H ⟶ RYE + cat2"
    },
    "RYA hydrogenation": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RYA + 2 cat-H ⟶ REA + cat2"
    },
    "Dimer generation1": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RYE + catX-RDEt ⟶ dimer + catX"
    },
    "Dimer generation2": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "REA + catX-RDEt ⟶ 2 H2 + dimer + catX"
    },
}
hydrogenation.plot_sensitivity_analysis(varied_mechanistic_params, operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="ee6e9f37-9cca-404f-b6e1-a35e148502a0" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ee6e9f37-9cca-404f-b6e1-a35e148502a0")) {                    Plotly.newPlot(                        "ee6e9f37-9cca-404f-b6e1-a35e148502a0",                        [{"hovertemplate":"Label=original [RDEt]\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eRDEt (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"original [RDEt]","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"original [RDEt]","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAA
A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAABpxi8pWGctP49MBXM9NjM\u002fu3na\u002fpXLOz\u002f8XSJJ2DRHPzt4L7CaW1U\u002fmksL2N1bYT\u002fuJmRtrRloPykNcFpp4m4\u002fe\u002f0L\u002fY3Zcj87hqhufkR2P+aIX2rDsHk\u002f63fASVMdfT+xaLFSh0SAP7oiFJaX+YE\u002fn39EqGqtgz8YGsMws1+FP51n2kInEIc\u002fyPa\u002ftYO+iD9QY8n6mGqKP3PNxY80FIw\u002fnwdukC27jT8OI+9GcF+PP3yf4qBxgJA\u002fsyrqdLlPkT\u002fY60xlih2SPzC0eRnb6ZI\u002f97zlu6i0kz9dpkfe7X2UP9AkXYCoRZU\u002fkTShddcLlj944RiyetCWP33UctGSk5c\u002fWuESCyJVmD9E8LkgKhWZP87vpkSu05k\u002f27kRWbGQmj\u002fIVHrZNkybP7whXjNDBpw\u002f7i6bY9q+nD+qtdN\u002fAXadPyvZ74+8K54\u002f1wc+5A\u002fgnj9CXal0AJOfP20D3V5JIqA\u002fa2m202V6oD\u002f0n2ZT2NGgPyKffM6jKKE\u002f8Dpm9sl+oT+hKBnmTNShP0HImqMvKaI\u002f9yNhWXR9oj9iF5oxHdGiP9TeGaYsJKM\u002f5FQII6V2oz8eji3+iMijPwN5S3LaGaQ\u002fjCkot5tqpD\u002fpgA35zrqkP\u002f7Yelp2CqU\u002fH8gf5JNZpT9FNnunKailP\u002fFAs5859qU\u002f1NIBycVDpj8w5CYP0JCmP+I4sFZa3aY\u002fJLMZdmYppz8N30099nSnP\u002fewWXALwKc\u002fDp5ix6cKqD86eO7xzFSoP47wk5V8nqg\u002fHBW\u002fTLjnqD9gmj2pgTCpP6U5bzTaeKk\u002fxifya8PAqT+ouRXIPgiqP\u002fWY8bRNT6o\u002fDB+Yl\u002fGVqj86eVHNK9yqP1dLCKn9Ias\u002f95FJeGhnqz9s9P59bayrP+BAlfYN8as\u002fJIokF0s1rD\u002fUPKULJnmsP+TPgfufvKw\u002fp7lpBLr\u002frD+zEM49dUKtP09kHbnShK0\u002ftCDLgNPGrT\u002fITw6ZeAiuP25qiv3CSa4\u002fjv8jprOKrj9oJL2DS8uuPwSj43+LC68\u002fawN4f3RLrz9RMGVhB4uvP4EJLQBFyq8\u002frEnpF5cEsD+p1p ...

# %% [markdown]
# ### Model calibration and identification
# We first compare prediction vs. experiment data using parameters without calibration

# %%
# load experiment data and print
exp_dataset = pd.read_csv("./cases/hydrogenation_dataset.csv")
exp_dataset
# Out:
#      m_rdy  t_b  temp  pressure  agitation  m_rdet  m_dimer  h2_used  \
# 0  0.10444  311    10         4       1200  0.0662  0.00244  0.00339
# 1  0.10444  309    20         4       1200  0.0838  0.00663  0.00445
# 2  0.09060  135    25        12       1200  0.0862  0.00362  0.00454
# 3  0.08520  352    25         4       1200  0.0739  0.00813  0.00410
# 4  0.08770  352     5        12       1200  0.0766  0.00133  0.00381
# 5  0.09120  234    20        10        600  0.0808  0.00407  0.00437
# 6  0.06910  239    25         4        600  0.0683  0.00881  0.00350
#
#    m_rdy_left
# 0     0.03330
# 1     0.01149
# 2     0.00252
# 3     0.00209
# 4     0.01380
# 5     0.00330
# 6     0.00016

# %%
# plot parity plots
hydrogenation.plot_simulation_parity(exp_dataset)
# Out:
# Squared error: 0.001220
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="83979edf-a7b8-473a-a239-a1bfe2eeb364" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("83979edf-a7b8-473a-a239-a1bfe2eeb364")) {                    Plotly.newPlot(                        "83979edf-a7b8-473a-a239-a1bfe2eeb364",                        [{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"bcX+snvysD\u002f5oGez6nO1P4xK6gQ0EbY\u002feqUsQxzrsj9ApN++DpyzPwFNhA1Pr7Q\u002fzhlR2ht8sT8="},"xaxis":"x","y":{"dtype":"f8","bdata":"yfQQG29HtD\u002fYNBY4HXm5P6TMVwFo0rQ\u002ffmspaNhStT\u002fucUm1EBi2P0nnvfOXtLY\u002fTvrxHKv9sD8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"seHplbIMoT+AK9mxEYiHP03bv7LSpGQ\u002frKjBNAwfYT9seHqlLEOMP0YldQKaCGs\u002f8WjjiLX4JD8="},"xaxis":"x2","y":{"dtype":"f8","bdata":"LCRMCDUsmD8wJ8V8ImRwP7AnpHXaunw\u002fni0Nb\u002ffGsD6XOpWZTqIYPzxNk\u002fLY3Uw\u002fMMEImzgL8D4="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"BcB4Bg39Yz9jesISDyh7P2SSkbOwp20\u002fEY3uIHamgD8KSzygbMpVP+vFUE60q3A\u002fCacFL\u002foKgj8="},"xaxis":"x3","y":{"dtype":"f8","bdata":"a9ajEVc7Nj8CIUViF61LP0Bc5UAI0FM\u002fGFlhviSIVD9v89FkZe4qP0b6sa8jhko\u002feIRg1j77Uz8="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"9iNFZFjFaz+1pnnHKTpyPw2mYfiImHI\u002fCRueXinLcD8uc7osJjZvPxEZVvFG5nE\u002feekmMQisbD8="},"xaxis":"x4","y":{"dtype":"f8","bdata":"pGrK8wm2cT\u002fvHEeAs\u002fV1P69ZNlC0T3I\u002fRdrEQdeacj8EA\u002fJs5UhzPwhcuOFjz3M\u002f9LxXde8rbj8="},"yaxis":"y4","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet"," ...

# %% [markdown]
# #### Determining parameters for calibration
# Recall reactions and mass transport phenomena
# - H2 + cat2 ⟶ 2 cat-H
# - 2 cat-H ⟶ H2 + cat2
# - RDY + 2 cat-H ⟶ RYE + cat2
# - RYE + 2 cat-H ⟶ RYA + cat2
# - RYA + 2 cat-H ⟶ REA + cat2
# - REA + 2 cat-H ⟶ RDEt + cat2
# - RDEt + catX ⟶ catX-RDEt
# - catX-RDEt ⟶ RDEt + catX
# - RYE + catX-RDEt ⟶ dimer + catX
# - REA + catX-RDEt ⟶ 2 H2 + dimer + catX
# - hydrogen dissolution
# - RDY dissolution
#
# Measurements
# - RDEt
# - Dimer
# - RDY undissolved
# - H2 used
#
# Parameters to be calibrated and their pristine values
# - RDY hydrogenation reaction [RDY + 2 cat-H ⟶ RYE + cat2]
#     Referenced_Reaction_Rate_Constant: 3 mol/L s
#     Activation_Energy: 30 kJ/mol
# - Dimer generation reaction [RYE + catX-RDEt ⟶ dimer + catX]
#     Referenced_Reaction_Rate_Constant: 1 mol/L s
#     Activation_Energy: 38 kJ/mol
# - Dimer generation reaction [REA + catX-RDEt ⟶ 2 H2 + dimer + catX]
#     Referenced_Reaction_Rate_Constant: 1 mol/L s
#     Activation_Energy: 38 kJ/mol

# %%
# run model calibration with differential_evolution algorithm for complex reaction network model
cal_param_ranges = [
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "RDY + 2 cat-H ⟶ RYE + cat2"}, 
        (0, 5)
    ),
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "RYE + catX-RDEt ⟶ dimer + catX"}, 
        (0, 10)
    ),
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "REA + catX-RDEt ⟶ 2 H2 + dimer + catX"}, 
        (0, 10)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "RDY + 2 cat-H ⟶ RYE + cat2"}, 
        (20, 80)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "RYE + catX-RDEt ⟶ dimer + catX"}, 
        (20, 80)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "REA + catX-RDEt ⟶ 2 H2 + dimer + catX"}, 
        (20, 80)
    ),
    (
        {"param": "Solid-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
         "solid": "Solid_Feedstock", 
         "stream": "Batch_Feed",
         "species": "RDY"}, 
        (0, 0.5)
    ),
    (
        {"param": "Gas-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
         "gas": "Gas_Flow", 
         "stream": "Batch_Feed",
         "species": "H2"}, 
        (0, 0.01)
    ),
]
cal_params = hydrogenation.calibrate(cal_param_ranges, exp_dataset)
# Out:
# differential_evolution step 1: f(x)= 0.0003844014556020769
# differential_evolution step 2: f(x)= 0.0003844014556020769
# differential_evolution step 3: f(x)= 0.0003844014556020769
# differential_evolution step 4: f(x)= 0.0003844014556020769
# differential_evolution step 5: f(x)= 0.0003844014556020769
# differential_evolution step 6: f(x)= 0.00035296633612976646
# differential_evolution step 7: f(x)= 0.00035296633612976646
# differential_evolution step 8: f(x)= 0.00033571849407291354

# %%
# Parity plot after model calibratioin
cal_reaction_params = [(k, v) for k, v in cal_params if k in [p[0] for p in hydrogenation.reaction_params()]]
cal_transport_params = [(k, v) for k, v in cal_params if k in [p[0] for p in hydrogenation.transport_params()]]
hydrogenation.plot_simulation_parity(exp_dataset, reaction_params = cal_reaction_params, transport_params = cal_transport_params)
# Out:
# Squared error: 0.000336
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="6c2037ab-60de-4bc5-8e57-a8dff36169bd" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6c2037ab-60de-4bc5-8e57-a8dff36169bd")) {                    Plotly.newPlot(                        "6c2037ab-60de-4bc5-8e57-a8dff36169bd",                        [{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"bcX+snvysD\u002f5oGez6nO1P4xK6gQ0EbY\u002feqUsQxzrsj9ApN++DpyzPwFNhA1Pr7Q\u002fzhlR2ht8sT8="},"xaxis":"x","y":{"dtype":"f8","bdata":"+42d7hcxsD+B6WO+bMu3P\u002fsL2hdKcrQ\u002fQHMWjjdQtD9tu1yqUseyPxZcTAf1dbY\u002fazXaqij+rz8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"seHplbIMoT+AK9mxEYiHP03bv7LSpGQ\u002frKjBNAwfYT9seHqlLEOMP0YldQKaCGs\u002f8WjjiLX4JD8="},"xaxis":"x2","y":{"dtype":"f8","bdata":"Y9\u002f1SiLVoz9UgHhFEYeCP21h+BUzdXQ\u002fivGDBu\u002fGsD6mR4gy+aSJP4bmof1xyko\u002fULJOfvDGsD4="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"BcB4Bg39Yz9jesISDyh7P2SSkbOwp20\u002fEY3uIHamgD8KSzygbMpVP+vFUE60q3A\u002fCacFL\u002foKgj8="},"xaxis":"x3","y":{"dtype":"f8","bdata":"UrpDTwmeVD9BJlzofQ9uP6D70cGqP3o\u002fIS8BJnPYej8qcQjbWmdGP9mkpwdpiG0\u002f\u002ftzD8Bl2ej8="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"9iNFZFjFaz+1pnnHKTpyPw2mYfiImHI\u002fCRueXinLcD8uc7osJjZvPxEZVvFG5nE\u002feekmMQisbD8="},"xaxis":"x4","y":{"dtype":"f8","bdata":"NyPj96GobD\u002fZD8Blp6B0P3sAECOWVnI\u002feIrzhE4vcj+oHmOoaoRwP9xuwtLXmXM\u002fk\u002f4w4\u002fFYbT8="},"yaxis":"y4","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet"," ...

# %%
# plot RDEt mass profiles under varied mechanistic parameters
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444),
    ({"param": "Temperature"}, 20),
    ({"param": "Pressure"},     4),
    ({"param": "Agitation"}, 1200),
    ({"param": "Batch_Time"}, 309),
]
varied_mechanistic_params = {
    "original": None,
    "H2 dissolution": {
        "param": "Gas-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
        "gas": "Gas_Flow", 
        "stream": "Batch_Feed", 
        "species": "H2"
    },
    "RDY dissolution": {
        "param": "Solid-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
        "solid": "Solid_Feedstock", 
        "stream": "Batch_Feed", 
        "species": "RDY"
    },
    "RDY hydrogenation": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RDY + 2 cat-H ⟶ RYE + cat2"
    },
    "RYA hydrogenation": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RYA + 2 cat-H ⟶ REA + cat2"
    },
    "Dimer generation1": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RYE + catX-RDEt ⟶ dimer + catX"
    },
    "Dimer generation2": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "REA + catX-RDEt ⟶ 2 H2 + dimer + catX"
    },
}
hydrogenation.plot_sensitivity_analysis(varied_mechanistic_params, operation_params, cal_reaction_params, cal_transport_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="a6267b53-5f5a-4963-b84a-d46dd820fc2a" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a6267b53-5f5a-4963-b84a-d46dd820fc2a")) {                    Plotly.newPlot(                        "a6267b53-5f5a-4963-b84a-d46dd820fc2a",                        [{"hovertemplate":"Label=original [RDEt]\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eRDEt (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"original [RDEt]","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"original [RDEt]","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAC5HoXrUbj4P7kehetRuAhAC9ejcD2KEkC5HoXrUbgYQGZmZmZm5h5AC9ejcD2KIkDhehSuR6ElQLkehetRuChAkML1KFzPK0BmZmZmZuYuQB+F61G4\u002fjBAC9ejcD2KMkD2KFyPwhU0QOF6FK5HoTVAzczMzMwsN0C5HoXrUbg4QKRwPQrXQzpAkML1KFzPO0B7FK5H4Vo9QGZmZmZm5j5AKVyPwvU4QEAfhetRuP5AQBSuR+F6xEFAC9ejcD2KQkAAAAAAAFBDQPYoXI\u002fCFURA7FG4HoXbREDhehSuR6FFQNejcD0KZ0ZAzczMzMwsR0DD9Shcj\u002fJHQLkehetRuEhArkfhehR+SUCkcD0K10NKQJqZmZmZCUtAkML1KFzPS0CF61G4HpVMQHsUrkfhWk1AcT0K16MgTkBmZmZmZuZOQF2PwvUorE9AKVyPwvU4UECkcD0K15tQQB+F61G4\u002flBAmpmZmZlhUUAUr
p+lT9w90OOJiuWP4Hcsi501pY\u002f2G8w23iAlz8yfMm7OSmYPx7bvD270Jg\u002fx0vxlgJ3mT9uDHyIFByaP\u002fAbq2z2v5o\u002fZu3OW61imz8+95RYPgScPxq0KVCupJw\u002fDEI5FgJEnT+cs6NtPuKdP0XKhwhof54\u002f8hvOfYMbnz+28CBNlbafP2PgdOxQKKA\u002ffUGrtdZ0oD+r9WYZ3sCgP9BbJyJpDKE\u002fl3FWzXlXoT9AwwAMEqKhP3yqzsIz7KE\u002fSG03yuA1oj9swQjvGn+iP0EiUvLjx6I\u002fn\u002fzkiT0Qoz+YoN1gKVijP\u002fItKBepn6M\u002fTWvAQr7moz9rZ41vai2kP02Eoh+vc6Q\u002ffg7qy425pD+Ti+njB\u002f+kP3qUZM4eRKU\u002fGrRN6dOIpT+\u002fmECKKM2lP+Ojof4dEaY\u002f+NIdjLVUpj8pEcNw8JemPxAPJ+PP2qY\u002fUTfaElUdpz+VwoEogV+nP8cU7EVVoac\u002fVrArhdLipz+KufH6+SOoPw+QgLjMZKg\u002fgYT5xUulqD99OgMheOWoP1Iy98lSJak\u002fY4Mdu9xkqT+Bw\u002f7kFqSpP66tAzAC46k\u002fVRljip8hqj+XfSHT71+qP2r4B+vznao\u002fsipnqazbqj80mKXiGhmrP3I4LmY\u002fVqs\u002fkPLxABuTqz9t8Z15rs+rP+DsJJP6C6w\u002fxPLXDwBIrD9gsaCnv4OsP+VGNhc6v6w\u002fRLaDEHD6rD9nP1FFY ...

# %% [markdown]
# #### Fitting model with constant RDY saturated concentration
# identify how should we model the RDY saturated concentration by comparing calibration results of different models

# %%
# Try to identify the best fitted model with different structures based on different phenomenons
# Here we recreate the model by injecting different phenomenons
# The hypotheis of this model is that the solid dissolution saturated concention is constant
phenos = {
    "Mass accumulation":    "Batch",
    "Flow pattern":         "Well_Mixed",
    "Mass transport":       ["Gas-Liquid_Mass_Transfer", "Solid-Liquid_Mass_Transfer"],
    "param law":            {
        "Gas_Dissolution_Saturated_Concentration": "Henry's_Law",
        "Solid_Dissolution_Saturated_Concentration": "Constant",
    },
}

hydrogenation = Hydrogenation(phenos, random_seed = 42)

# %%
# Run calibration again to calibrate the solid saturation concentration along with other parameters
cal_param_ranges = [
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "RDY + 2 cat-H ⟶ RYE + cat2"}, 
        (0, 5)
    ),
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "RYE + catX-RDEt ⟶ dimer + catX"}, 
        (0, 10)
    ),
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "REA + catX-RDEt ⟶ 2 H2 + dimer + catX"}, 
        (0, 10)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "RDY + 2 cat-H ⟶ RYE + cat2"}, 
        (20, 80)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "RYE + catX-RDEt ⟶ dimer + catX"}, 
        (20, 80)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "REA + catX-RDEt ⟶ 2 H2 + dimer + catX"}, 
        (20, 80)
    ),
    (
        {"param": "Solid-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
         "solid": "Solid_Feedstock", 
         "stream": "Batch_Feed",
         "species": "RDY"}, 
        (0, 0.5)
    ),
    (
        {"param": "Gas-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
         "gas": "Gas_Flow", 
         "stream": "Batch_Feed",
         "species": "H2"}, 
        (0, 0.01)
    ),
    (
        {"param": "Constant_Solid_Saturated_Concentration", 
         "solid": "Solid_Feedstock", 
         "stream": "Batch_Feed",
         "species": "RDY"}, 
        (0, 0.003)
    )
]
cal_params = hydrogenation.calibrate(cal_param_ranges, exp_dataset)
# Out:
# differential_evolution step 1: f(x)= 0.0007047570925086062
# differential_evolution step 2: f(x)= 0.0007047570925086062
# differential_evolution step 3: f(x)= 0.0007047570925086062
# differential_evolution step 4: f(x)= 0.0007047570925086062
# differential_evolution step 5: f(x)= 0.0007047570925086062
# differential_evolution step 6: f(x)= 0.0006698622782477428
# differential_evolution step 7: f(x)= 0.0006698622782477428
# differential_evolution step 8: f(x)= 0.0006698622782477428

# %%
# Plot the pred vs. exp result
# Model with constant solid saturation concentration has a larger error after fitting
# This suggests that RDY dissolution is more reasonable to be modelled using the fitted relationship S_RDY = func([RDEt])
cal_reaction_params = [(k, v) for k, v in cal_params if k in [p[0] for p in hydrogenation.reaction_params()]]
cal_transport_params = [(k, v) for k, v in cal_params if k in [p[0] for p in hydrogenation.transport_params()]]
hydrogenation.plot_simulation_parity(exp_dataset, reaction_params=cal_reaction_params, transport_params=cal_transport_params)
# Out:
# Squared error: 0.000670
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="2ea507e8-2bd7-4e94-b7e2-8e710d5fc2fa" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2ea507e8-2bd7-4e94-b7e2-8e710d5fc2fa")) {                    Plotly.newPlot(                        "2ea507e8-2bd7-4e94-b7e2-8e710d5fc2fa",                        [{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"bcX+snvysD\u002f5oGez6nO1P4xK6gQ0EbY\u002feqUsQxzrsj9ApN++DpyzPwFNhA1Pr7Q\u002fzhlR2ht8sT8="},"xaxis":"x","y":{"dtype":"f8","bdata":"2itfkOtbsj+5XmJsDAu6P3P8cqJcZ7U\u002fketDuGv2sz8\u002fgZFGGxKzP\u002fDXee0vgLY\u002fSZYKOgpyrz8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"seHplbIMoT+AK9mxEYiHP03bv7LSpGQ\u002frKjBNAwfYT9seHqlLEOMP0YldQKaCGs\u002f8WjjiLX4JD8="},"xaxis":"x2","y":{"dtype":"f8","bdata":"igTHHGx6nz9xHkXD88awPvLHvZXwxrA+jFRLJPXGsD7z9ygVeAyIP6Q6SkXyxrA+d\u002fgQvfbGsD4="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"BcB4Bg39Yz9jesISDyh7P2SSkbOwp20\u002fEY3uIHamgD8KSzygbMpVP+vFUE60q3A\u002fCacFL\u002foKgj8="},"xaxis":"x3","y":{"dtype":"f8","bdata":"HptwBwv7Vz9ALE7P2ldyP9jQ\u002fZ3nSoA\u002fZS0eLPQsgD9n4tCXfClKP4+deNo16HE\u002fvY8RjcPBfj8="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"9iNFZFjFaz+1pnnHKTpyPw2mYfiImHI\u002fCRueXinLcD8uc7osJjZvPxEZVvFG5nE\u002feekmMQisbD8="},"xaxis":"x4","y":{"dtype":"f8","bdata":"vmB9ZjMKcD99JIrKCI52P3h72BPvUXM\u002fxUIlvwYUcj\u002fnB5HkCqlwP+amgCj+uHM\u002fUm8xXWAubT8="},"yaxis":"y4","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinew ...
