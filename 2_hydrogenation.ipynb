# %% [markdown]
# # Hydrogenation Case
#
# <!-- <div><img src="cases/hydrogenation_process_scheme.jpg" width="600"/></div> -->
# ![](./cases/hydrogenation_process_scheme.png)
#
# This case models a chemical process in which R-di-yne (RDY) undergoes hydrogenation to produce R-di-ethyl (RDEt).
# During the process, RDY and hydrogen gas are dissolved in a mixed liquid of water and an unknown solvent, with
# agitation applied to promote mass transfer. A cooling jacket is used to remove the heat generated by the exothermic
# hydrogenation reactions.
# The di-yne group of RDY is progressively hydrogenated by the catalyst (cat-H) through a sequence of intermediates —
# RDY → RYE → RYA → REA → RDEt. In addition, side reactions leading to dimer formation may occur during the process.
#
# The reaction scheme is like:
# ![](./cases/hydrogenation_reaction_scheme.png)
#
# Reactions:
# - H2 + cat2 > 2 cat-H
# - 2 cat-H > H2 + cat2
# - RDY + 2 cat-H > RYE + cat2
# - RYE + 2 cat-H > RYA + cat2
# - RYA + 2 cat-H > REA + cat2
# - REA + 2 cat-H > RDEt + cat2
# - RDEt + catX > catX-RDEt
# - catX-RDEt > RDEt + catX
# - RYE + catX-RDEt > dimer + catX
# - REA + catX-RDEt > 2 H2 + dimer + catX
#
# Mass Transfer:
# The gas-liquid and solid-liquid coefficients are correlated to agitation speed as $k_La = DN^\alpha$ and $k_Sa = DN^\alpha$, respectively
#
# In this notebook, we go through model simulation and identify the rate-limiting step of the hydrogenation reaction.
# Then, sensitivity analysis is applied to identify parameters for model calibration.
# Finally, we run model calibration with different mass transport behaviours for model identification.

# %%
# Import required python libraries
import pandas as pd
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

from cases.hydrogenation_agitation import Hydrogenation


# Define phenomenon for the process to define the model
# RDY saturated concentration is fitted with RDEt concentration
# Supported phenomenon options:
# "Mass transport":
#       []
#       ["Gas-Liquid_Mass_Transfer"]
#       ["Solid-Liquid_Mass_Transfer"]
#       ["Gas-Liquid_Mass_Transfer", "Solid-Liquid_Mass_Transfer"],
# if "Gas-Liquid_Mass_Transfer" occurs, "Gas_Dissolution_Saturated_Concentration" can be "Henry's_Law" or "Constant" 
# if "Solid-Liquid_Mass_Transfer" occurs, "Solid_Dissolution_Saturated_Concentration" can be "Fitted" or "Constant" 
# RDY dissolution saturated concentration is found dependent on RDEt concentration, a relationship has been fitted and 
# included in the `hydrogenation.py` file for modelling
phenos = {
    "Mass accumulation":    "Batch",
    "Flow pattern":         "Well_Mixed",
    "Mass transport":       ["Gas-Liquid_Mass_Transfer", "Solid-Liquid_Mass_Transfer"],
    "param law":            {
        "Gas_Dissolution_Saturated_Concentration": "Henry's_Law",
        "Solid_Dissolution_Saturated_Concentration": "Fitted", 
    },
}

hydrogenation = Hydrogenation(phenos, random_seed=42)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %% [markdown]
# ### Model Simulation and Rate-limiting Step analysis
# In this section, we run hydrogenation simulation with guessed kinetic parameters to visualise concentration profiles of reactants, intermediates, and products.
# Rate-limiting step is analysed by plotting intermediate mass profiles and rates of reaction and mass transport, which is further confirmed by sensitivity analysis.

# %%
# List operation parameters
# During experiments, masses of used water, solvent, and catalysts are fixed
for operation_param in hydrogenation.operation_params():
    print(operation_param)
# Out:
# ({'param': 'Initial_Mass', 'stream': 'Batch_Feed', 'species': 'water'}, 0.2574)
# ({'param': 'Initial_Mass', 'stream': 'Batch_Feed', 'species': 'solvent'}, 0.194)
# ({'param': 'Initial_Mass', 'stream': 'Batch_Feed', 'species': 'cat2'}, 0.00235)
# ({'param': 'Initial_Mass', 'stream': 'Batch_Feed', 'species': 'catX'}, 0.00235)
# ({'param': 'Mass_Gas_Fraction', 'gas': 'Gas_Flow', 'species': 'H2'}, 1.0)
# ({'param': 'Initial_Mass_Solid', 'solid': 'Solid_Feedstock', 'species': 'RDY'}, None)
# ({'param': 'Temperature'}, None)
# ({'param': 'Pressure'}, None)
# ({'param': 'Agitation'}, None)
# ({'param': 'Batch_Time'}, None)

# %%
# Model simulation and concentration profile plot
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444), # kg
    ({"param": "Temperature"}, 20), # oC
    ({"param": "Pressure"},     4), # bar
    ({"param": "Agitation"}, 1200), # rpm
    ({"param": "Batch_Time"}, 309), # min
]
hydrogenation.plot_simulation_profiles(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="68a25432-fc42-47e9-ad2b-cc9e580f2e4e" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("68a25432-fc42-47e9-ad2b-cc9e580f2e4e")) {                    Plotly.newPlot(                        "68a25432-fc42-47e9-ad2b-cc9e580f2e4e",                        [{"hovertemplate":"Species=RDEt\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eMass (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RDEt","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RDEt","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAC5HoXrUbj4P7kehetRuAhAC9ejcD2KEkC5HoXrUbgYQGZmZmZm5h5AC9ejcD2KIkDhehSuR6ElQLkehetRuChAkML1KFzPK0BmZmZmZuYuQB+F61G4\u002fjBAC9ejcD2KMkD2KFyPwhU0QOF6FK5HoTVAzczMzMwsN0C5HoXrUbg4QKRwPQrXQzpAkML1KFzPO0B7FK5H4Vo9QGZmZmZm5j5AKVyPwvU4QEAfhetRuP5AQBSuR+F6xEFAC9ejcD2KQkAAAAAAAFBDQPYoXI\u002fCFURA7FG4HoXbREDhehSuR6FFQNejcD0KZ0ZAzczMzMwsR0DD9Shcj\u002fJHQLkehetRuEhArkfhehR+SUCkcD0K10NKQJqZmZmZCUtAkML1KFzPS0CF61G4HpVMQHsUrkfhWk1AcT0K16MgTkBmZmZmZuZOQF2PwvUorE9AKVyPwvU4UECkcD0K15tQQB+F61G4\u002flBAmpmZmZlhUUAUrkfhesRRQJDC9ShcJ1JAC9ejcD2KUkCF61G4Hu1SQAAAAAAAUFNAexSuR+GyU0D2KFyPwhVUQHE9CtejeFRA7FG4HoXbVEBmZmZmZj5VQOF6FK5HoVVAXY\u002fC9SgEVkDXo3A9CmdWQFK4HoXryVZAzczMzMwsV0BH4XoUro9XQMP1KFyP8ldAPgrXo3BVWEC5HoXrUbhYQDMzMzMzG1lArkfhehR+WUAqXI\u002fC9eBZQKRwPQrXQ1pAH4XrUbimWkCamZmZmQlbQBSuR+F6bFtAkML1KFzPW0AL16NwPTJcQIXrUbgelVxAAAAAAAD4XEB7FK5H4VpdQPYoXI\u002fCvV1AcT0K16MgXkDsUbgehYNeQGZmZmZm5l5A4XoUrkdJX0Bdj8L1KKxfQOxRuB6FB2BAKVyPwvU4YEBmZmZmZmpgQKRwPQrXm2BA4noUrk
VjNK9yqP91jD6n9Ias\u002fWKBQeGhnqz\u002fz+wV+bayrP0JAnPYN8as\u002fTYUrF0s1rD\u002fUM6wLJnmsP9u+iPufvKw\u002f2ZlwBLr\u002frD9X1tQ9dUKtP1sUJLnShK0\u002fpr\u002fRgNPGrT9K7RSZeAiuP+4Nkf3CSa4\u002f3LkqprOKrj\u002f+B8SDS8uuP5ag6n+LC68\u002f1v5+f3RLrz8l+GthB4uvP5aEMwBFyq8\u002f0UjsF5cEsD8TiZ\u002ff4S ...

# %%
# Plot all reaction and mass transfer rates
# Rates of "H2 dissolution" and "H2 + cat2 <> 2 cat-H" are relatively fast
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444), # kg
    ({"param": "Temperature"}, 20), # oC
    ({"param": "Pressure"},     4), # bar
    ({"param": "Agitation"}, 1200), # rpm
    ({"param": "Batch_Time"}, 309), # min
]
steps = [
    "H2 + cat2 > 2 cat-H",
    "2 cat-H > H2 + cat2",
    "RDY + 2 cat-H > RYE + cat2",
    "RYE + 2 cat-H > RYA + cat2",
    "RYA + 2 cat-H > REA + cat2",
    "REA + 2 cat-H > RDEt + cat2",
    "RDEt + catX > catX-RDEt",
    "catX-RDEt > RDEt + catX",
    "RYE + catX-RDEt > dimer + catX",
    "REA + catX-RDEt > 2 H2 + dimer + catX",
    "H2 dissolution", 
    "RDY dissolution"
]
hydrogenation.plot_simulation_rates(steps, operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="5ee86b03-8252-458f-9542-28c074a560d4" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5ee86b03-8252-458f-9542-28c074a560d4")) {                    Plotly.newPlot(                        "5ee86b03-8252-458f-9542-28c074a560d4",                        [{"hovertemplate":"Reaction\u002fMass transport=H2 + cat2 \u003e 2 cat-H\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eRate (mol\u002fL s)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 + cat2 \u003e 2 cat-H","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"H2 + cat2 \u003e 2 cat-H","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAC5HoXrUbj4P7kehetRuAhAC9ejcD2KEkC5HoXrUbgYQGZmZmZm5h5AC9ejcD2KIkDhehSuR6ElQLkehetRuChAkML1KFzPK0BmZmZmZuYuQB+F61G4\u002fjBAC9ejcD2KMkD2KFyPwhU0QOF6FK5HoTVAzczMzMwsN0C5HoXrUbg4QKRwPQrXQzpAkML1KFzPO0B7FK5H4Vo9QGZmZmZm5j5AKVyPwvU4QEAfhetRuP5AQBSuR+F6xEFAC9ejcD2KQkAAAAAAAFBDQPYoXI\u002fCFURA7FG4HoXbREDhehSuR6FFQNejcD0KZ0ZAzczMzMwsR0DD9Shcj\u002fJHQLkehetRuEhArkfhehR+SUCkcD0K10NKQJqZmZmZCUtAkML1KFzPS0CF61G4HpVMQHsUrkfhWk1AcT0K16MgTkBmZmZmZuZOQF2PwvUorE9AKVyPwvU4UECkcD0K15tQQB+F61G4\u002flBAmpmZmZlhUUAUrkfhesRRQJDC9ShcJ1JAC9ejcD2KUkCF61G4Hu1SQAAAAAAAUFNAexSuR+GyU0D2KFyPwhVUQHE9CtejeFRA7FG4HoXbVEBmZmZmZj5VQOF6FK5HoVVAXY\u002fC9SgEVkDXo3A9CmdWQFK4HoXryVZAzczMzMwsV0BH4XoUro9XQMP1KFyP8ld
2jz9Ii5aCoG+PPyxTY6OHaI8\u002fRkr5xW9hjz9WvfZtWVqPPyAN9uREU48\u002feWQeSjJMjz8InlxgIkWPPyWQ\u002fvsVPo8\u002fYwedTww3jz\u002fF7YGnBTCPP83D5GcCKY8\u002fce7odAMijz9ydzEbCRuPP7u1k\u002foSFI8\u002fQyWnXSENjz\u002fp3lN0NAaPP2hj+I1M\u002f44\u002f+rwjw2n4jj8OG349jPGOP1u\u002f7yO06o4\u002f1PxrmOHjjj9LRJa3FN2OP4UU9p9N1o4\u002fIyutcYzPjj\u002f1bpNG0ciOPwyXbDgcwo4\u002fgWCeX227jj+yRJnSxLSOP58nc6Qiro4\u002fffQV6Ianjj+gL7Ou8aCOP5kfPA5jmo4\u002fs2XVFtuTjj8NgMnZWY2OP1s0NGXfho4\u002fEmSnyWuAjj\u002fDOQMW\u002f3mOP1xQW1aZc44\u002fc ...

# %%
# Plot only rates of reactions from RDY to RDEt and RDY dissolution rate
# note that there's rate-limiting step in the series of hydrogenation reaction based on the overlapped rate curves
# RDY and RYE accumulate rapidly and then decay slowly
# if "RDY dissolution" is the rate-limiting step, there will be no RDY and RYA mass accumulation
# if "RYA + 2 cat-H > REA + cat2" is the rate-limiting step, RYA will accumulate which is not the case
# Therefore, "RDY + 2 cat-H > RYE + cat2" is the rate-limiting step, and RDY concentration rises close
# to the saturated concentration to slow down the solid RDY consumption rate
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444), # kg
    ({"param": "Temperature"}, 20), # oC
    ({"param": "Pressure"},     4), # bar
    ({"param": "Agitation"}, 1200), # rpm
    ({"param": "Batch_Time"}, 309), # min
]
steps = [
    "RDY + 2 cat-H > RYE + cat2",
    "RYE + 2 cat-H > RYA + cat2",
    "RYA + 2 cat-H > REA + cat2",
    "REA + 2 cat-H > RDEt + cat2",
    "RDY dissolution"
]
hydrogenation.plot_simulation_rates(steps, operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="25fabefa-01f9-4542-9162-f3dd589399d7" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("25fabefa-01f9-4542-9162-f3dd589399d7")) {                    Plotly.newPlot(                        "25fabefa-01f9-4542-9162-f3dd589399d7",                        [{"hovertemplate":"Reaction\u002fMass transport=RDY + 2 cat-H \u003e RYE + cat2\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eRate (mol\u002fL s)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RDY + 2 cat-H \u003e RYE + cat2","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RDY + 2 cat-H \u003e RYE + cat2","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAC5HoXrUbj4P7kehetRuAhAC9ejcD2KEkC5HoXrUbgYQGZmZmZm5h5AC9ejcD2KIkDhehSuR6ElQLkehetRuChAkML1KFzPK0BmZmZmZuYuQB+F61G4\u002fjBAC9ejcD2KMkD2KFyPwhU0QOF6FK5HoTVAzczMzMwsN0C5HoXrUbg4QKRwPQrXQzpAkML1KFzPO0B7FK5H4Vo9QGZmZmZm5j5AKVyPwvU4QEAfhetRuP5AQBSuR+F6xEFAC9ejcD2KQkAAAAAAAFBDQPYoXI\u002fCFURA7FG4HoXbREDhehSuR6FFQNejcD0KZ0ZAzczMzMwsR0DD9Shcj\u002fJHQLkehetRuEhArkfhehR+SUCkcD0K10NKQJqZmZmZCUtAkML1KFzPS0CF61G4HpVM
ywNnr5pIB4\u002frGXH4PbOHT+21hvfcn8dP22FfxfNMR0\u002fmGE3P+7lHD9CLehwyJscP4xffWdKUxw\u002f0+iqWGMMHD+aaRMMA8cbP1DKMGQXgxs\u002fIMt4RpBAGz\u002fjQOw0fP8aP+eG0M36vxo\u002f9f9SlXqBGj\u002fICmMYVkQaPw70jz1iCBo\u002fkzTP9pzNGT9V2FBX+5MZP0ODMGlzWxk\u002fDKMCf\u002fwjGT+XZWIbju0YPyY2vyYguBg\u002fo5HQy6qDGD9hPNNjJlAYP1ZZN5CLHRg\u002fdXRjl9PrFz+wppEg+LoXP0RRKZfyihc\u002fm50JLbxbFz\u002fdcYWVTy0XP+qnIsin\u002fxY\u002fcAU33L3SFj8EJgCfjKYWP7pSgA4PexY\u002f9dauw0BQFj\u002fLWBQWHSYWP\u002fqJuNae\u002fBU\u002fLL3Gt8HTFT8kn19mgasVP+v4C73ZgxU\u002f4DqXr8ZcFT8qK45eRDYVP9tDGA5PEBU\u002fB8VDGOPqFD\u002fFb4Pr\u002fMUUP6rC\u002fyeZoRQ\u002fIBgQYLR9FD85tF9eS1oUP3N+OgBbNxQ\u002f8AeuPeAUFD\u002fVv6Em2PITPwY0M+Y\u002f0RM\u002fiaMGwBSwEz+C268MVI8TPzThvgn7bhM\u002ffAAZLgdPEz+ii0fvdS8TP0Fauc9EEBM\u002fqJ+zV3HxEj9c ...

# %%
# Plot sensitivity analysis results
# We increase some parameters to 1.5 times of their values and visualise their influences on output
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444), # kg
    ({"param": "Temperature"}, 20), # oC
    ({"param": "Pressure"},     4), # bar
    ({"param": "Agitation"}, 1200), # rpm
    ({"param": "Batch_Time"}, 309), # min
]
varied_mechanistic_params = {
    "original": None,
    "H2 dissolution": {
        "param": "Gas-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
        "gas": "Gas_Flow", 
        "stream": "Batch_Feed", 
        "species": "H2"
    },
    "RDY dissolution": {
        "param": "Solid-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
        "solid": "Solid_Feedstock", 
        "stream": "Batch_Feed", 
        "species": "RDY"
    },
    "RDY hydrogenation": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RDY + 2 cat-H > RYE + cat2"
    },
    "RYA hydrogenation": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RYA + 2 cat-H > REA + cat2"
    },
    "Dimer generation1": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RYE + catX-RDEt > dimer + catX"
    },
    "Dimer generation2": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "REA + catX-RDEt > 2 H2 + dimer + catX"
    },
}
hydrogenation.plot_sensitivity_analysis(varied_mechanistic_params, operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="a54972ec-7e6a-41f6-9a97-421fa1b9b811" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a54972ec-7e6a-41f6-9a97-421fa1b9b811")) {                    Plotly.newPlot(                        "a54972ec-7e6a-41f6-9a97-421fa1b9b811",                        [{"hovertemplate":"Label=original [RDEt]\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eRDEt (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"original [RDEt]","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"original [RDEt]","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAA
u002fSlXGtYO+iD\u002fI4tP6mGqKP17n0Y80FIw\u002fYjCBkC27jT8Hq\u002ftGcF+PP\u002f6p66BxgJA\u002fIwbwdLlPkT8v6FJlih2SPzDzfRnb6ZI\u002fCj\u002fpu6i0kz9JsEre7X2UP+DyX4CoRZU\u002ffNajddcLlj9TUxuyetCWP7ckddGSk5c\u002f9OAUCyJVmD9ZXbwgKhWZP16eqESu05k\u002fOrsTWbGQmj+svnzZNkybP5uKYTNDBpw\u002fqROeY9q+nD\u002fzDNR\u002fAXadP6bF74+8K54\u002fGDhB5A\u002fgnj+Gm7N0AJOfPxLA4F5JIqA\u002fhGuy02V6oD9HA1xT2NGgP3ioes6jKKE\u002fTtVv9sl+oT+w2CHmTNShP5rjoqMvKaI\u002fNLFpWXR9oj\u002fAFaMxHdGiP9nOIqYsJKM\u002fT14RI6V2oz9yizb+iMijP4BYVHLaGaQ\u002ffeQwt5tqpD+YDhb5zrqkP+NVg1p2CqU\u002fkSYo5JNZpT+cioOnKailP9d9u5859qU\u002f1AYKycVDpj8gDC8P0JCmP3k7uFZa3aY\u002fE6EhdmYppz9jt1U99nSnP+R5YXALwKc\u002f4VJqx6cKqD\u002fBFfbxzFSoP9h4m5V8nqg\u002faY3GTLjnqD\u002fpAUWpgTCpP0CUdjTaeKk\u002f6HX5a8PAqT8R\u002fRzIPgiqP83T+LRNT6o\u002fwk2fl\u002fGVqj\u002f2nVjNK9yqP91jD6n9Ias\u002fWKBQeGhnqz\u002fz+wV+bayrP0JAnPYN8as\u002fTYUrF0s1rD\u002fUM6wLJnmsP9u+iPufvKw\u002f2ZlwBLr\u002frD9X1tQ9dUKtP1sUJLnShK0\u002fpr\u002fRgNPGrT9K7RSZeAiuP+4Nkf3CSa4\u002f3LkqprOKrj\u002f+B8SDS8uuP5ag6n+LC68\u002f1v5+f3RLrz8l+GthB4uvP5aEMwBFyq8\u002f0UjsF5cEs ...

# %% [markdown]
# ### Model calibration and identification
# We first compare prediction vs. experiment data using parameters without calibration

# %%
# load experiment data and print
exp_dataset = pd.read_csv("./cases/hydrogenation_dataset.csv")
exp_dataset
# Out:
#      m_rdy  t_b  temp  pressure  agitation  m_rdet  m_dimer  h2_used  \
# 0  0.10444  311    10         4       1200  0.0662  0.00244  0.00339
# 1  0.10444  309    20         4       1200  0.0838  0.00663  0.00445
# 2  0.09060  135    25        12       1200  0.0862  0.00362  0.00454
# 3  0.08520  352    25         4       1200  0.0739  0.00813  0.00410
# 4  0.08770  352     5        12       1200  0.0766  0.00133  0.00381
# 5  0.09120  234    20        10        600  0.0808  0.00407  0.00437
# 6  0.06910  239    25         4        600  0.0683  0.00881  0.00350
#
#    m_rdy_left
# 0     0.03330
# 1     0.01149
# 2     0.00252
# 3     0.00209
# 4     0.01380
# 5     0.00330
# 6     0.00016

# %%
# plot parity plots
hydrogenation.plot_simulation_parity(exp_dataset)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="ec7d6cf7-d512-4572-9d56-c6d02b83e511" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ec7d6cf7-d512-4572-9d56-c6d02b83e511")) {                    Plotly.newPlot(                        "ec7d6cf7-d512-4572-9d56-c6d02b83e511",                        [{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"bcX+snvysD\u002f5oGez6nO1P4xK6gQ0EbY\u002feqUsQxzrsj9ApN++DpyzPwFNhA1Pr7Q\u002fzhlR2ht8sT8="},"xaxis":"x","y":{"dtype":"f8","bdata":"NAVZ+o1HtD+iq6Y3HXm5P9X0YgFo0rQ\u002fdbw7aNhStT9GvYcvCRi2PwiFzPCXtLY\u002fqWzrHKv9sD8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"seHplbIMoT+AK9mxEYiHP03bv7LSpGQ\u002frKjBNAwfYT9seHqlLEOMP0YldQKaCGs\u002f8WjjiLX4JD8="},"xaxis":"x2","y":{"dtype":"f8","bdata":"+549478rmD9lpi+DImRwP\u002f0ZAnXaunw\u002fZmO7E\u002fTGsD647ETp470YP2KS3FDa3Uw\u002fB\u002fEm9TgL8D4="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"BcB4Bg39Yz9jesISDyh7P2SSkbOwp20\u002fEY3uIHamgD8KSzygbMpVP+vFUE60q3A\u002fCacFL\u002foKgj8="},"xaxis":"x3","y":{"dtype":"f8","bdata":"4wpLPVc7Nj\u002foS0RiF61LPxfY4UAI0FM\u002fjO4AwSSIVD8MgmTBZe4qP9pVX68jhko\u002f1op31j77Uz8="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"9iNFZFjFaz+1pnnHKTpyPw2mYfiImHI\u002fCRueXinLcD8uc7osJjZvPxEZVvFG5nE\u002feekmMQisbD8="},"xaxis":"x4","y":{"dtype":"f8","bdata":"5FiG+CK2cT+Taut\u002fs\u002fV1P92ePFC0T3I\u002fQwK\u002fQdeacj+sX35d30hzP2LRaN9jz3M\u002fV9tXde8rbj8="},"yaxis":"y4","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet"," ...

# %% [markdown]
# #### Determining parameters for calibration
# Recall reactions and mass transport phenomena
# - H2 + cat2 > 2 cat-H
# - 2 cat-H > H2 + cat2
# - RDY + 2 cat-H > RYE + cat2
# - RYE + 2 cat-H > RYA + cat2
# - RYA + 2 cat-H > REA + cat2
# - REA + 2 cat-H > RDEt + cat2
# - RDEt + catX > catX-RDEt
# - catX-RDEt > RDEt + catX
# - RYE + catX-RDEt > dimer + catX
# - REA + catX-RDEt > 2 H2 + dimer + catX
# - hydrogen dissolution
# - RDY dissolution
#
# Measurements
# - RDEt
# - Dimer
# - RDY undissolved
# - H2 used
#
# Parameters to be calibrated and their pristine values
# - RDY hydrogenation reaction [RDY + 2 cat-H > RYE + cat2]
#     Referenced_Reaction_Rate_Constant: 3 mol/L s
#     Activation_Energy: 30 kJ/mol
# - Dimer generation reaction [RYE + catX-RDEt > dimer + catX]
#     Referenced_Reaction_Rate_Constant: 1 mol/L s
#     Activation_Energy: 38 kJ/mol
# - Dimer generation reaction [REA + catX-RDEt > 2 H2 + dimer + catX]
#     Referenced_Reaction_Rate_Constant: 1 mol/L s
#     Activation_Energy: 38 kJ/mol

# %%
# run model calibration with differential_evolution algorithm for complex reaction network model
cal_param_ranges = [
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "RDY + 2 cat-H > RYE + cat2"}, 
        (0, 5)
    ),
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "RYE + catX-RDEt > dimer + catX"}, 
        (0, 10)
    ),
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "REA + catX-RDEt > 2 H2 + dimer + catX"}, 
        (0, 10)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "RDY + 2 cat-H > RYE + cat2"}, 
        (20, 80)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "RYE + catX-RDEt > dimer + catX"}, 
        (20, 80)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "REA + catX-RDEt > 2 H2 + dimer + catX"}, 
        (20, 80)
    ),
    (
        {"param": "Solid-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
         "solid": "Solid_Feedstock", 
         "stream": "Batch_Feed",
         "species": "RDY"}, 
        (0, 0.5)
    ),
    (
        {"param": "Gas-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
         "gas": "Gas_Flow", 
         "stream": "Batch_Feed",
         "species": "H2"}, 
        (0, 0.01)
    ),
]
cal_params = hydrogenation.calibrate(cal_param_ranges, exp_dataset)
# Out:
# differential_evolution step 1: f(x)= 0.00038440122435757314
# differential_evolution step 2: f(x)= 0.00038440122435757314
# differential_evolution step 3: f(x)= 0.00038440122435757314
# differential_evolution step 4: f(x)= 0.00038440122435757314
# differential_evolution step 5: f(x)= 0.00038440122435757314
# differential_evolution step 6: f(x)= 0.0003529656086186397
# differential_evolution step 7: f(x)= 0.0003529656086186397
# differential_evolution step 8: f(x)= 0.0003357342109087516
# differential_evolution step 9: f(x)= 0.0003357342109087516
# differential_evolution step 10: f(x)= 0.0003179945213583795
# differential_evolution step 11: f(x)= 0.0003179945213583795
# differential_evolution step 12: f(x)= 0.0003098293209127628
# differential_evolution step 13: f(x)= 0.0003098293209127628
# differential_evolution step 14: f(x)= 0.00030314362864726784
# differential_evolution step 15: f(x)= 0.00030314362864726784
# differential_evolution step 16: f(x)= 0.00029931678732733857
# differential_evolution step 17: f(x)= 0.00029931678732733857
# differential_evolution step 18: f(x)= 0.00028047397577613393
# differential_evolution step 19: f(x)= 0.00028047397577613393
# differential_evolution step 20: f(x)= 0.00028047397577613393

# %%
# Parity plot after model calibratioin
cal_reaction_params = [(k, v) for k, v in cal_params if k in [p[0] for p in hydrogenation.reaction_params()]]
cal_transport_params = [(k, v) for k, v in cal_params if k in [p[0] for p in hydrogenation.transport_params()]]
hydrogenation.plot_simulation_parity(exp_dataset, reaction_params=cal_reaction_params, transport_params=cal_transport_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="26924906-aa9d-4b79-b07f-3a990c3fe825" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("26924906-aa9d-4b79-b07f-3a990c3fe825")) {                    Plotly.newPlot(                        "26924906-aa9d-4b79-b07f-3a990c3fe825",                        [{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"bcX+snvysD\u002f5oGez6nO1P4xK6gQ0EbY\u002feqUsQxzrsj9ApN++DpyzPwFNhA1Pr7Q\u002fzhlR2ht8sT8="},"xaxis":"x","y":{"dtype":"f8","bdata":"SXm2b15lsD9QAGNERDu3P3D\u002fXjdDbbQ\u002f\u002fgZB8ioStD9F3fJ2ar2zPz1Cc7R8Q7Y\u002fRCf163SArz8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"seHplbIMoT+AK9mxEYiHP03bv7LSpGQ\u002frKjBNAwfYT9seHqlLEOMP0YldQKaCGs\u002f8WjjiLX4JD8="},"xaxis":"x2","y":{"dtype":"f8","bdata":"zp3xA\u002fNJoz\u002fNlGl3MsOEPyyIlFKZDHE\u002f8w\u002fIovbGsD4dCeddV+OBP8iaiLfmu0Q\u002f7XJ89+XF4j4="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"BcB4Bg39Yz9jesISDyh7P2SSkbOwp20\u002fEY3uIHamgD8KSzygbMpVP+vFUE60q3A\u002fCacFL\u002foKgj8="},"xaxis":"x3","y":{"dtype":"f8","bdata":"Yp9KiYAEYD\u002f8GtncQElzP8bPQvDhFn4\u002fdS7DNGOmfj83Lv5QdJhUPxuASHQW5nI\u002fke2YbbNHfj8="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"9iNFZFjFaz+1pnnHKTpyPw2mYfiImHI\u002fCRueXinLcD8uc7osJjZvPxEZVvFG5nE\u002feekmMQisbD8="},"xaxis":"x4","y":{"dtype":"f8","bdata":"fiS377QAbT+eJmoX2Ux0P24cbcoJcXI\u002f1lC4t3Qccj\u002flj0CfR0xxPw\u002fAiN2Gj3M\u002fyn9P+SMybT8="},"yaxis":"y4","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarp ...

# %%
# plot RDEt mass profiles under varied mechanistic parameters
operation_params = [
    ({"param": "Initial_Mass_Solid", "solid": "Solid_Feedstock", "species": "RDY"}, 0.10444), # kg
    ({"param": "Temperature"}, 20), # oC
    ({"param": "Pressure"},     4), # bar
    ({"param": "Agitation"}, 1200), # rpm
    ({"param": "Batch_Time"}, 309), # min
]
varied_mechanistic_params = {
    "original": None,
    "H2 dissolution": {
        "param": "Gas-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
        "gas": "Gas_Flow", 
        "stream": "Batch_Feed", 
        "species": "H2"
    },
    "RDY dissolution": {
        "param": "Solid-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
        "solid": "Solid_Feedstock", 
        "stream": "Batch_Feed", 
        "species": "RDY"
    },
    "RDY hydrogenation": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RDY + 2 cat-H > RYE + cat2"
    },
    "RYA hydrogenation": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RYA + 2 cat-H > REA + cat2"
    },
    "Dimer generation1": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "RYE + catX-RDEt > dimer + catX"
    },
    "Dimer generation2": {
        "param": "Referenced_Reaction_Rate_Constant", 
        "stream": "Batch_Feed", 
        "reaction": "REA + catX-RDEt > 2 H2 + dimer + catX"
    },
}
hydrogenation.plot_sensitivity_analysis(varied_mechanistic_params, operation_params, cal_reaction_params, cal_transport_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="447afc25-0652-4b70-9f97-dd738471f4b3" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("447afc25-0652-4b70-9f97-dd738471f4b3")) {                    Plotly.newPlot(                        "447afc25-0652-4b70-9f97-dd738471f4b3",                        [{"hovertemplate":"Label=original [RDEt]\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eRDEt (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"original [RDEt]","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"original [RDEt]","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAC5HoXrUbj4P7kehetRuAhAC9ejcD2KEkC5HoXrUbgYQGZmZmZm5h5AC9ejcD2KIkDhehSuR6ElQLkehetRuChAkML1KFzPK0BmZmZmZuYuQB+F61G4\u002fjBAC9ejcD2KMkD2KFyPwhU0QOF6FK5HoTVAzczMzMwsN0C5HoXrUbg4QKRwPQrXQzpAkML1KFzPO0B7FK5H4Vo9QGZmZmZm5j5AKVyPwvU4QEAfhetRuP5AQBSuR+F6xEFAC9ejcD2KQkAAAAAAAFBDQPYoXI\u002fCFURA7FG4HoXbREDhehSuR6FFQNejcD0KZ0ZAzczMzMwsR0DD9Shcj\u002fJHQLkehetRuEhArkfhehR+SUCkcD0K10NKQJqZmZmZCUtAkML1KFzPS0CF61G4HpVMQHsUrkfhWk1AcT0K16MgTkBmZmZmZuZOQF2PwvUorE9AKVyPwvU4UECkcD0K15tQQB+F61G4\u002flBAmpmZmZlhUUAUrkfhesRRQJDC9ShcJ1JAC9ejcD2KUkCF61G4Hu1SQAAAAAAAUFNAexSuR+GyU0D2KFyPwhVUQHE9CtejeFRA7FG4HoXbVEBmZmZmZj5VQOF6FK5HoVVAXY\u002fC9SgEVkDXo3A9CmdWQFK4HoXryVZAzczMzMw
znT+nEaetJsmdPwDU89g0Xp4\u002fah5xHnzynj9NfLXW\u002foWfP02jrahfDKA\u002fh0J56l9VoD8XbSdPAZ6gPzdjWvBE5qA\u002f9zOw4isuoT+5Nw42t3WhP3clhfXnvKE\u002f1v9ZJ78Doj8unRXNPUqiP\u002fGhjONkkKI\u002fGPLsYjXWoj8DY+M+sBujP\u002fqAkGbWYKM\u002fQHjLxKiloz8UEyBAKOqjPyNG8bpVLqQ\u002fSOd7EzJypD\u002f4bvQjvrWkP0sokcL6+KQ\u002fbNKrweg7pT+oEtjviH6lP4\u002fMCRjcwKU\u002fPxugAeMCpj\u002fynINwnkSmP+mKoSQPhqY\u002fwZqt2jXHpj+psm1MEwinP76INTCoSKc\u002fqET\u002fOPWIpz+\u002fsk8W+8inPwza0nS6CKg\u002fAbyw\u002fjNIqD8dIsNbaIeoPzUhqTBYxqg\u002fQk6GHgQFqT+GqJvAbEOpP0LpWrGSgak\u002fReiMiHa\u002fqT9bP2TiGP2pP ...

# %% [markdown]
# #### Fitting model with constant RDY saturated concentration
# identify how should we model the RDY saturated concentration by comparing calibration results of different models

# %%
# Try to identify the best fitted model with different structures based on different phenomenons
# Here we recreate the model by injecting different phenomenons
# The hypotheis of this model is that the solid dissolution saturated concention is constant
phenos = {
    "Mass accumulation":    "Batch",
    "Flow pattern":         "Well_Mixed",
    "Mass transport":       ["Gas-Liquid_Mass_Transfer", "Solid-Liquid_Mass_Transfer"],
    "param law":            {
        "Gas_Dissolution_Saturated_Concentration": "Henry's_Law",
        "Solid_Dissolution_Saturated_Concentration": "Constant",
    },
}

hydrogenation = Hydrogenation(phenos, random_seed=42)

# %%
# Run calibration again to calibrate the solid saturation concentration along with other parameters
cal_param_ranges = [
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "RDY + 2 cat-H > RYE + cat2"}, 
        (0, 5)
    ),
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "RYE + catX-RDEt > dimer + catX"}, 
        (0, 10)
    ),
    (
        {"param": "Referenced_Reaction_Rate_Constant", 
         "stream": "Batch_Feed", 
         "reaction": "REA + catX-RDEt > 2 H2 + dimer + catX"}, 
        (0, 10)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "RDY + 2 cat-H > RYE + cat2"}, 
        (20, 80)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "RYE + catX-RDEt > dimer + catX"}, 
        (20, 80)
    ),
    (
        {"param": "Activation_Energy", 
         "stream": "Batch_Feed", 
         "reaction": "REA + catX-RDEt > 2 H2 + dimer + catX"}, 
        (20, 80)
    ),
    (
        {"param": "Solid-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
         "solid": "Solid_Feedstock", 
         "stream": "Batch_Feed",
         "species": "RDY"}, 
        (0, 0.5)
    ),
    (
        {"param": "Gas-Liquid_Volumetric_Mass_Transfer_Coefficient_D", 
         "gas": "Gas_Flow", 
         "stream": "Batch_Feed",
         "species": "H2"}, 
        (0, 0.01)
    ),
    (
        {"param": "Constant_Solid_Saturated_Concentration", 
         "solid": "Solid_Feedstock", 
         "stream": "Batch_Feed",
         "species": "RDY"}, 
        (0, 0.003)
    )
]
cal_params = hydrogenation.calibrate(cal_param_ranges, exp_dataset)
# Out:
# differential_evolution step 1: f(x)= 0.0007047571087240911
# differential_evolution step 2: f(x)= 0.0007047571087240911
# differential_evolution step 3: f(x)= 0.0007047571087240911
# differential_evolution step 4: f(x)= 0.0007047571087240911
# differential_evolution step 5: f(x)= 0.0007047571087240911
# differential_evolution step 6: f(x)= 0.0006698597298065127
# differential_evolution step 7: f(x)= 0.0006698597298065127
# differential_evolution step 8: f(x)= 0.0006698597298065127
# differential_evolution step 9: f(x)= 0.000663333322023111
# differential_evolution step 10: f(x)= 0.000663333322023111
# differential_evolution step 11: f(x)= 0.000663333322023111
# differential_evolution step 12: f(x)= 0.000663333322023111
# differential_evolution step 13: f(x)= 0.000663333322023111
# differential_evolution step 14: f(x)= 0.000663333322023111
# differential_evolution step 15: f(x)= 0.0006492808218655062
# differential_evolution step 16: f(x)= 0.0006492808218655062
# differential_evolution step 17: f(x)= 0.0006492808218655062
# differential_evolution step 18: f(x)= 0.0006492808218655062
# differential_evolution step 19: f(x)= 0.0006492808218655062
# differential_evolution step 20: f(x)= 0.0006492808218655062

# %%
# Plot the pred vs. exp result
# Model with constant solid saturation concentration has a larger error after fitting
# This suggests that RDY dissolution is more reasonable to be modelled using the fitted relationship S_RDY = func([RDEt])
cal_reaction_params = [(k, v) for k, v in cal_params if k in [p[0] for p in hydrogenation.reaction_params()]]
cal_transport_params = [(k, v) for k, v in cal_params if k in [p[0] for p in hydrogenation.transport_params()]]
hydrogenation.plot_simulation_parity(exp_dataset, reaction_params=cal_reaction_params, transport_params=cal_transport_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="dc91826e-5f31-4712-a4cc-e1a747134eb6" class="plotly-graph-div" style="height:900px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dc91826e-5f31-4712-a4cc-e1a747134eb6")) {                    Plotly.newPlot(                        "dc91826e-5f31-4712-a4cc-e1a747134eb6",                        [{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"bcX+snvysD\u002f5oGez6nO1P4xK6gQ0EbY\u002feqUsQxzrsj9ApN++DpyzPwFNhA1Pr7Q\u002fzhlR2ht8sT8="},"xaxis":"x","y":{"dtype":"f8","bdata":"VRqr\u002fYzDsT+pHaCfdvy5P1a3uP+ONLU\u002fdSCF66e\u002fsz\u002fSULfxNOOyP6ShU7TDdbY\u002fHht0EaQMrz8="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"seHplbIMoT+AK9mxEYiHP03bv7LSpGQ\u002frKjBNAwfYT9seHqlLEOMP0YldQKaCGs\u002f8WjjiLX4JD8="},"xaxis":"x2","y":{"dtype":"f8","bdata":"mliF68zpoD9zrTai9MawPiDZGidoyuo+C+bmPfbGsD5IGjwufpOJP3w5mtnDnc4+GYHHj8jCvj4="},"yaxis":"y2","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"BcB4Bg39Yz9jesISDyh7P2SSkbOwp20\u002fEY3uIHamgD8KSzygbMpVP+vFUE60q3A\u002fCacFL\u002foKgj8="},"xaxis":"x3","y":{"dtype":"f8","bdata":"1idcdKRFVj8mdaI2yTxzP5APUS4j04E\u002ftZiHP8HagT93N+TOT5BGP0KJZZPdiHI\u002fLVE8cE\u002fugD8="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Experiment=%{x}\u003cbr\u003ePrediction=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"9iNFZFjFaz+1pnnHKTpyPw2mYfiImHI\u002fCRueXinLcD8uc7osJjZvPxEZVvFG5nE\u002feekmMQisbD8="},"xaxis":"x4","y":{"dtype":"f8","bdata":"rzwIOhYXbz9JMXdzmol2P5JS4dkRQnM\u002fQuaPd2MDcj9Dwfyq7YFwPxs1FIm6tXM\u002fX21ecYEPbT8="},"yaxis":"y4","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth" ...
